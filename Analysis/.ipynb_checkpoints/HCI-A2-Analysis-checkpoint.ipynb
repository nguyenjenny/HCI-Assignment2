# %%
class AnalysisHCI:

    def __init__(self, directory):
        # print('Make sure the directory has forward slashes')
        import os
        import pandas as pd
        self.directory = directory
        self.fileNameDF = self.FileNameDF()
        self.rawData = self.RawData()
        self.ProcessData()
        os.chdir(directory)
        
    def FileNameDF(self):
        import pandas as pd
        import numpy as np
        import glob
        self.fileNameDF = pd.DataFrame(columns=['file'])
        self.fileNameDF['file'] = glob.glob('participant_*')  
        self.fileNameDF.sort_values(by=['file'], inplace=True)
        return  self.fileNameDF
    def RawData(self):
        import pandas as pd
        self.rawData = pd.DataFrame()
        for file in self.fileNameDF['file']:
            f = open(file, "r")
            j = f.readline()
            f.close()
            df = pd.DataFrame(eval(f'[{j}]'))
            df['file'] = file
            self.rawData = pd.concat([self.rawData, df], axis=0)
        self.rawData.set_index('file', inplace=True)
        self.rawData['screenSize'] = self.rawData['scale'].map(lambda x: 38 if x == 0.2405 else 42 )
        return self.rawData
    def Fuzzy (self, targetPhrase,inputText):    
        from fuzzywuzzy import fuzz
        from fuzzywuzzy import process
        return fuzz.ratio(targetPhrase,inputText)
    def getCorrect (self, targetPhrase, inputText):
        count = 0
        stop = min(len(targetPhrase), len(inputText))
        for i, char in enumerate(targetPhrase):
            if i == stop:
                break
            if char == inputText[i]:
                count += 1
        return count  
    def getIF (self, targetPhrase,inputPhrase):
        import re
        inputPhrase = inputPhrase.replace('-delete-', '<')
        deletes = re.findall(r'<+',inputPhrase) # all the block of deletes that have been entered ('<<', '<', '<<<')
        m = re.findall(r'([\w\s]*)<+([\w\s]*)',inputPhrase) # the characters before and after the delete
        indexes = [ i.start() for i in re.finditer(r'<+',inputPhrase)] # the indexes of all the delete blocks
        count = 0 # count of all the incorrect fixes
        print(inputPhrase)
        print(targetPhrase)
        for i, s in enumerate(m):
            error, replace = s
            length = len(deletes[i])
#             priorDeletes = 0 if len(''.join(deletes[0:i])) == 0 else len(''.join(deletes[0:i])) + 1
            priorDeletes = len(''.join(deletes[0:i]))*2
            index = indexes[i] - length - priorDeletes
            replace = replace[:length]
            correctReplace = targetPhrase[index:index+length] 
#             print(f'replace: [{replace}]\tcorrect: [{correctReplace}]')
            count += self.getCorrect(correctReplace, replace)
            print(f'replace: [{replace}]\tcorrect: [{correctReplace}]')
        print(f'Count: {count}\n')
        return count

    def ProcessData (self):
        from fuzzywuzzy import fuzz
        from fuzzywuzzy import process
        fuzzyResult = []
        correctResult = []
        ifResult = []
        for f in self.rawData.index:
            file = self.rawData.loc[f]
            inputPhrase = file.inputPhrase
            inputText = file.inputText
            targetPhrase = file.targetPhrase
            fuzzyResult.append(fuzz.ratio(targetPhrase,inputText))
            correctResult.append(self.getCorrect(targetPhrase, inputText))
            ifResult.append(self.getIF(targetPhrase,inputPhrase))
        self.rawData['fuzzyRatio'] = fuzzyResult
        self.rawData['correct'] = correctResult
        self.rawData['IF'] = ifResult
        self.rawData['characters'] =  self.rawData['targetPhrase'].map(lambda x: len(x))
        self.rawData['INF'] = self.rawData['keyPressedTimes'] -  self.rawData['correct'] - 2* self.rawData['deleteTimes']
        self.rawData['accuracy/time/char'] = self.rawData['fuzzyRatio']/self.rawData['time']/self.rawData['characters']
        self.rawData['totalErrorRate'] = (self.rawData['INF'] + self.rawData['IF'])/(self.rawData['correct'] +self.rawData['INF'] + self.rawData['IF'])
        return self.rawData
    def totalErrorPivot (self):
        return self.rawData.pivot_table( index='id', columns= ["screenSize", 'type'], values='totalErrorRate')

# %%
directory = '/Users/jenny/Documents/School/IBBME/CSC2514/CSC2514-Assignments/HCI-Assignment2/Analysis/Data/ParticipantData'
a2 = AnalysisHCI(directory)
# Out:
# all good boyd<s f<ded<serve fudge
# all good boys deserve fudge
# replace: [s]	correct: [s]
# replace: [d]	correct: [d]
# replace: [s]	correct: [s]
# Count: 3
#
# obligations must bd <<e mey<t first
# obligations must be met first
# replace: [e ]	correct: [e ]
# replace: [t]	correct: [t]
# Count: 3
#
# a<a picture is worth ,a<<,a< <<<m< mamy<<ny words
# a picture is worth many words
# replace: [a]	correct: [a]
# replace: []	correct: [ma]
# replace: [ ]	correct: [a]
# replace: [m]	correct: [ ma]
# replace: [ ]	correct: [ ]
# replace: [ny]	correct: [ny]
# Count: 4
#
# p.<leade<<se keep this co n<<nfidential
# please keep this confidential
# replace: [l]	correct: [l]
# replace: [se]	correct: [se]
# replace: [nf]	correct: [nf]
# Count: 5
#
# what a monl<ket <<y sers<<es a mo m<<nkey wil.<<..<<ll dp<o
# what a monkey sees a monkey will do
# replace: [k]	correct: [k]
# replace: [y ]	correct: [y ]
# replace: [es]	correct: [es]
# replace: [nk]	correct: [nk]
# replace: []	correct: [ll]
# replace: [ll]	correct: [ll]
# replace: [o]	correct: [o]
# Count: 10
#
# motiba<<vational semimz<<narz<s mame<<ke mr<e so<ick
# motivational seminars make me sick
# replace: [va]	correct: [va]
# replace: [na]	correct: [na]
# replace: [s]	correct: [s]
# replace: [ke]	correct: [ke]
# replace: [e]	correct: [e]
# replace: [i]	correct: [i]
# Count: 9
#
# be persix<stant to wu<i n<<n a stro<uk<<ike
# be persistent to win a strike
# replace: [s]	correct: [s]
# replace: [i]	correct: [i]
# replace: [n ]	correct: [n ]
# replace: [u]	correct: [i]
# replace: [ik]	correct: [ik]
# Count: 6
#
# drove my chevy to the levee
# drove my chevy to the levee
# Count: 0
#
# the insulation ix<s mo<<not working
# the insulation is not working
# replace: [s]	correct: [s]
# replace: [no]	correct: [no]
# Count: 3
#
# please take a bath tni<<his mp<ontn<<th
# please take a bath this month
# replace: [hi]	correct: [hi]
# replace: [o]	correct: [o]
# replace: [th]	correct: [th]
# Count: 5
#
# he coi<oled off after shd<r<e lrg<<eft
# he cooled off after she left
# replace: [o]	correct: [o]
# replace: [r]	correct: [e]
# replace: [e]	correct: [e]
# replace: [ef]	correct: [ef]
# Count: 4
#
# arguinb<g with tb<ne<<he boss is futile
# arguing with the boss is futile
# replace: [g]	correct: [g]
# replace: [n]	correct: [h]
# replace: [he]	correct: [he]
# Count: 3
#
# taking the train is usually fadye<<<ster
# taking the train is usually faster
# replace: [ste]	correct: [ste]
# Count: 3
#
# ypu<<pu<<p<ou ,u<<must mz<ake an appointmem<nt
# you must make an appointment
# replace: [pu]	correct: [ou]
# replace: [p]	correct: [ou]
# replace: [o]	correct: [o]
# replace: [mu]	correct: [mu]
# replace: [a]	correct: [a]
# replace: [n]	correct: [n]
# Count: 6
#
# teaching servicex <<s will help
# teaching services will help
# replace: [s ]	correct: [s ]
# Count: 2
#
# sent this by registeg<rec<d mail
# sent this by registered mail
# replace: [r]	correct: [r]
# replace: [d]	correct: [d]
# Count: 2
#
# we dine pu<<pu<<p<out pn<<on tjr<<nr<<he wr<eeld<<kenfs<<fs<<dx<s
# we dine out on the weekends
# replace: [pu]	correct: [ou]
# replace: [p]	correct: [ou]
# replace: [o]	correct: [o]
# replace: [on]	correct: [on]
# replace: [nr]	correct: [he]
# replace: [he]	correct: [he]
# replace: [e]	correct: [e]
# replace: [ke]	correct: [ke]
# replace: [fs]	correct: [ds]
# replace: [dx]	correct: [ds]
# replace: [s]	correct: [s]
# Count: 12
#
# my mother makes good cookies
# my mother makes good cookies
# Count: 0
#
# sing theg< gospel and the blues
# sing the gospel and the blues
# replace: [ ]	correct: [ ]
# Count: 1
#
# experience ish<<s hard to cp<ome by
# experience is hard to come by
# replace: [s ]	correct: [s ]
# replace: [o]	correct: [o]
# Count: 3
#
# go out for some pizza and beer
# go out for some pizza and beer
# Count: 0
#
# everybody looses in custody battles
# everybody looses in custody battles
# Count: 0
#
# he p,<layec<c<d a li<<pimp i  <n<<n that  o<movie
# he played a pimp in that movie
# replace: [l]	correct: [l]
# replace: [c]	correct: [d]
# replace: [d]	correct: [d]
# replace: [pi]	correct: [pi]
# replace: [n]	correct: [ ]
# replace: [n ]	correct: [n ]
# replace: [m]	correct: [o]
# Count: 6
#
# pay off a mortgage for a house
# pay off a mortgage for a house
# Count: 0
#
# your presem< n<<ntation was inspirinf<g
# your presentation was inspiring
# replace: [ ]	correct: [n]
# replace: [nt]	correct: [nt]
# replace: [g]	correct: [g]
# Count: 3
#
# the assault took six months<<hs
# the assault took six months
# replace: [hs]	correct: [hs]
# Count: 2
#
# dolphins leap high out of the water
# dolphins leap high out of the water
# Count: 0
#
# medieval times were veru<<ry hard
# medieval times were very hard
# replace: [ry]	correct: [ry]
# Count: 2
#
# i like baroque and classical mux<sic
# i like baroque and classical music
# replace: [s]	correct: [s]
# Count: 1
#
# there wi.<ll be some fog tonign<ht
# there will be some fog tonight
# replace: [l]	correct: [l]
# replace: [h]	correct: [h]
# Count: 2
#
# the rationz<ale behind the desic<<<cision
# the rationale behind the decision
# replace: [a]	correct: [a]
# replace: [cis]	correct: [cis]
# Count: 4
#
# well connectec<d with pr<eople
# well connected with people
# replace: [d]	correct: [d]
# replace: [e]	correct: [e]
# Count: 2
#
# where did you get such a silly idea
# where did you get such a silly idea
# Count: 0
#
# all together in one ni<<big pi.<le
# all together in one big pile
# replace: [bi]	correct: [bi]
# replace: [l]	correct: [l]
# Count: 3
#
# win first prize in the contest
# win first prize in the contest
# Count: 0
#
# i watched bo<lazing saddles
# i watched blazing saddles
# replace: [l]	correct: [l]
# Count: 1
#
# vi<ote according to y <our conscience
# vote according to your conscience
# replace: [o]	correct: [o]
# replace: [o]	correct: [o]
# Count: 2
#
# neither ay< borrower nor a lendr<er v<be
# neither a borrower nor a lender be
# replace: [ ]	correct: [ ]
# replace: [e]	correct: [e]
# replace: [b]	correct: [b]
# Count: 3
#
# why doy< you<<ou ask silly questions
# why do you ask silly questions
# replace: [ ]	correct: [ ]
# replace: [ou]	correct: [ou]
# Count: 3
#
# frequently asked questions
# frequently asked questions
# Count: 0
#
# electric cars need big fuel cells
# electric cars need big fuel cells
# Count: 0
#
# we are subjects and must obey
# we are subjects and must obey
# Count: 0
#
# i spi.l<<lled coffee on the carpet
# i spilled coffee on the carpet
# replace: [ll]	correct: [ll]
# Count: 2
#
# histof<ro<ic  e<meetinv <<g without a rex<sult
# historic meeting without a result
# replace: [r]	correct: [r]
# replace: [i]	correct: [i]
# replace: [m]	correct: [e]
# replace: [g ]	correct: [ w]
# replace: [s]	correct: [u]
# Count: 2
#
# a good respo s<<nxe<<se to gn<<the quext<<stjo<<iom<n
# a good response to the question
# replace: [nx]	correct: [ns]
# replace: [se]	correct: [se]
# replace: [th]	correct: [th]
# replace: [st]	correct: [st]
# replace: [io]	correct: [io]
# replace: [n]	correct: [n]
# Count: 10
#
# gas<b<s bills are sent monthly
# gas bills are sent monthly
# replace: [b]	correct: [s]
# replace: [s]	correct: [s]
# Count: 1
#
# pib<<u b<<blic trz<ansit ix<s much gz<<g<fad<ster
# public transit is much faster
# replace: [u ]	correct: [ub]
# replace: [bl]	correct: [bl]
# replace: [a]	correct: [a]
# replace: [s]	correct: [s]
# replace: [g]	correct: [fa]
# replace: [f]	correct: [f]
# replace: [s]	correct: [s]
# Count: 7
#
# pae<rking lot is full of trucks
# parking lot is full of trucks
# replace: [r]	correct: [r]
# Count: 1
#
# the second largest country
# the second largest country
# Count: 0
#
# my preferred treat iss< chocolate
# my preferred treat is chocolate
# replace: [ ]	correct: [ ]
# Count: 1
#
# the presidential suite is very busy
# the presidential suite is very busy
# Count: 0
#
# one hour is allotted for questions
# one hour is allotted for questions
# Count: 0
#
# ta<<every saturday he folds the laundry
# every saturday he folds the laundry
# replace: [ev]	correct: [ev]
# Count: 2
#
# everybody looses in custody battles
# everybody looses in custody battles
# Count: 0
#
# players mustk< know all the rules
# players must know all the rules
# replace: [ ]	correct: [ ]
# Count: 1
#
# y<it< took the rover from the shop
# i took the rover from the shop
# replace: [i]	correct: [i]
# replace: [ ]	correct: [ ]
# Count: 2
#
# taking the train is usually faster
# taking the train is usually faster
# Count: 0
#
# the cat has a pleasent temperament
# the cat has a pleasant temperament
# Count: 0
#
# so you think you s<deserve a raise
# so you think you deserve a raise
# replace: [d]	correct: [d]
# Count: 1
#
# there will be some fog tonight
# there will be some fog tonight
# Count: 0
#
# our housekeepet<r does a thorough job
# our housekeeper does a thorough job
# replace: [r]	correct: [r]
# Count: 1
#
# arguing with the boss is futile
# arguing with the boss is futile
# Count: 0
#
# rapidly running short on words
# rapidly running short on words
# Count: 0
#
# at<t< tumor is ok provided it is benign
# a tumor is ok provided it is benign
# replace: [t]	correct: [ ]
# replace: [ ]	correct: [ ]
# Count: 1
#
# neother<<<<<<either a borrower nor a lender bw<e
# neither a borrower nor a lender be
# replace: [either]	correct: [either]
# replace: [e]	correct: [e]
# Count: 7
#
# thh<e pen is  ightiet<<<<<<< mif<ghtier than the sword
# the pen is mightier than the sword
# replace: [e]	correct: [e]
# replace: [ mif]	correct: [ightier]
# replace: [g]	correct: [t]
# Count: 1
#
# li,<mited warrg<abt<<nty of two years
# limited warranty of two years
# replace: [m]	correct: [m]
# replace: [a]	correct: [a]
# replace: [nt]	correct: [nt]
# Count: 4
#
# wx<<exwe<<erciae<<se ia <<s good for tge<<he minx<d
# exercise is good for the mind
# replace: [ex]	correct: [ex]
# replace: [er]	correct: [er]
# replace: [se]	correct: [se]
# replace: [s ]	correct: [s ]
# replace: [he]	correct: [he]
# replace: [d]	correct: [d]
# Count: 11
#
# these barracks arw bi<<<<e big enough
# these barracks are big enough
# replace: [e bi]	correct: [e bi]
# Count: 4
#
# people bliw <<<ow their horn a ,o<<lot
# people blow their horn a lot
# replace: [ow ]	correct: [ow ]
# replace: [lo]	correct: [lo]
# Count: 5
#
# movie about a nutty professor
# movie about a nutty professor
# Count: 0
#
# bank transactiom<ns was not registee<red
# bank transaction was not registered
# replace: [n]	correct: [n]
# replace: [r]	correct: [e]
# Count: 1
#
# an airport ias <<<s a very busy pk<lace
# an airport is a very busy place
# replace: [s a]	correct: [s a]
# replace: [l]	correct: [l]
# Count: 4
#
# wge<<hw<ere did u<you bey<<<get that tie
# where did you get that tie
# replace: [hw]	correct: [he]
# replace: [e]	correct: [e]
# replace: [y]	correct: [y]
# replace: [get]	correct: [get]
# Count: 6
#
# wga<<g<hat to do when tnd<<he oil runs dry
# what to do when the oil runs dry
# replace: [g]	correct: [ha]
# replace: [h]	correct: [h]
# replace: [he]	correct: [he]
# Count: 3
#
# every apple dro<<<from e er<<<very tree
# every apple from every tree
# replace: [fro]	correct: [fro]
# replace: [ver]	correct: [ver]
# Count: 6
#
# tge<<he dow jones index has riae<<a<xe<<seb<n
# the dow jones index has risen
# replace: [he]	correct: [he]
# replace: [a]	correct: [se]
# replace: [x]	correct: [s]
# replace: [se]	correct: [se]
# replace: [n]	correct: [n]
# Count: 5
#
# you e<will loose yiy <<<our vou<ice
# you will loose your voice
# replace: [w]	correct: [w]
# replace: [our]	correct: [our]
# replace: [i]	correct: [i]
# Count: 5
#
# ec<xcesc<<ed the ma x<<ximy<u m<<m speed ,<limit
# exceed the maximum speed limit
# replace: [x]	correct: [x]
# replace: [ed]	correct: [ed]
# replace: [xi]	correct: [xi]
# replace: [u]	correct: [u]
# replace: [m ]	correct: [m ]
# replace: [l]	correct: [l]
# Count: 9
#
# prayer im <<n s h<c<<cg<hools offends some
# prayer in schools offends some
# replace: [n ]	correct: [n ]
# replace: [c]	correct: [h]
# replace: [cg]	correct: [ch]
# replace: [h]	correct: [h]
# Count: 4
#
# interacyin<<<tip<om<ns betwew<d<en men and wp<omen
# interactions between men and women
# replace: [tip]	correct: [tio]
# replace: [o]	correct: [o]
# replace: [n]	correct: [n]
# replace: [d]	correct: [e]
# replace: [e]	correct: [e]
# replace: [o]	correct: [o]
# Count: 6
#
# the first time he tried to swim
# the first time he tried to swim
# Count: 0
#
# the earlj<y birdge<< geys <<<ta<s thd<e worm
# the early bird gets the worm
# replace: [y]	correct: [y]
# replace: [ g]	correct: [ g]
# replace: [ta]	correct: [ts ]
# replace: [s]	correct: [s]
# replace: [e]	correct: [e]
# Count: 6
#
# reala<<<lations ate<<re vwr<<ery strained < <
# relations are very strained
# replace: [lat]	correct: [lat]
# replace: [re]	correct: [re]
# replace: [er]	correct: [er]
# replace: [ ]	correct: []
# replace: []	correct: []
# Count: 7
#
# s<z<a coupom<n for a cre<<<free za<<sample
# a coupon for a free sample
# replace: [z]	correct: [a]
# replace: [a]	correct: [a]
# replace: [n]	correct: [n]
# replace: [fre]	correct: [fre]
# replace: [sa]	correct: [sa]
# Count: 7
#
# dolphims<<ns leap high out of the water
# dolphins leap high out of the water
# replace: [ns]	correct: [ns]
# Count: 2
#
# seasones <<d golfers po<<love the gaj<me
# seasoned golfers love the game
# replace: [d ]	correct: [d ]
# replace: [lo]	correct: [lo]
# replace: [m]	correct: [m]
# Count: 5
#
# a swcurit<<<<<<ecurity v<foo<r c<<ce of eight thousand
# a security force of eight thousand
# replace: [ecurit]	correct: [ecurit]
# replace: [f]	correct: [f]
# replace: [r]	correct: [r]
# replace: [ce]	correct: [ce]
# Count: 10
#
# parkinf<g lots << is du<<full of trucks
# parking lot is full of trucks
# replace: [g]	correct: [g]
# replace: [ i]	correct: [ i]
# replace: [fu]	correct: [fu]
# Count: 5
#
# a good rezpi<<<spom<m<nse ro <<<r<to tge<<ge<<he qhwsti<<<<<uws<<ew<stion
# a good response to the question
# replace: [spo]	correct: [spo]
# replace: [m]	correct: [n]
# replace: [n]	correct: [n]
# replace: [r]	correct: [to ]
# replace: [t]	correct: [t]
# replace: [ge]	correct: [he]
# replace: [he]	correct: [he]
# replace: [uws]	correct: [uesti]
# replace: [ew]	correct: [es]
# replace: [s]	correct: [s]
# Count: 12
#
# fall is my fa our<<<<vorite ze<<season
# fall is my favorite season
# replace: [vori]	correct: [vori]
# replace: [se]	correct: [se]
# Count: 6
#
# important for political parties
# important for political parties
# Count: 0
#
# reading week is just about here
# reading week is just about here
# Count: 0
#
# wear a crown with many jewels
# wear a crown with many jewels
# Count: 0
#
# circumstances are unacceptable
# circumstances are unacceptable
# Count: 0
#
# win first prize in the contest
# win first prize in the contest
# Count: 0

# %%
a2.rawData
# Out:
#                             deleteTimes id  \
# file
# participant_1_trial_1.txt             3  1
# participant_1_trial_10.txt            3  1
# participant_1_trial_11.txt           10  1
# participant_1_trial_12.txt            5  1
# participant_1_trial_13.txt           12  1
# participant_1_trial_14.txt            9  1
# participant_1_trial_15.txt            7  1
# participant_1_trial_16.txt            0  1
# participant_1_trial_17.txt            3  1
# participant_1_trial_18.txt            5  1
# participant_1_trial_19.txt            5  1
# participant_1_trial_2.txt             4  1
# participant_1_trial_20.txt            3  1
# participant_1_trial_21.txt            9  1
# participant_1_trial_22.txt            2  1
# participant_1_trial_23.txt            2  1
# participant_1_trial_24.txt           19  1
# participant_1_trial_25.txt            0  1
# participant_1_trial_26.txt            1  1
# participant_1_trial_27.txt            3  1
# participant_1_trial_28.txt            0  1
# participant_1_trial_29.txt            0  1
# participant_1_trial_3.txt             9  1
# participant_1_trial_30.txt            0  1
# participant_1_trial_31.txt            4  1
# participant_1_trial_32.txt            2  1
# participant_1_trial_33.txt            0  1
# participant_1_trial_34.txt            2  1
# participant_1_trial_35.txt            1  1
# participant_1_trial_36.txt            2  1
# ...                                 ... ..
# participant_3_trial_26.txt            4  3
# participant_3_trial_27.txt           11  3
# participant_3_trial_28.txt            4  3
# participant_3_trial_29.txt            5  3
# participant_3_trial_3.txt             0  3
# participant_3_trial_30.txt            2  3
# participant_3_trial_31.txt            4  3
# participant_3_trial_32.txt            7  3
# participant_3_trial_33.txt            5  3
# participant_3_trial_34.txt            6  3
# participant_3_trial_35.txt            8  3
# participant_3_trial_36.txt            5  3
# participant_3_trial_37.txt            9  3
# participant_3_trial_38.txt            6  3
# participant_3_trial_39.txt            8  3
# participant_3_trial_4.txt             0  3
# participant_3_trial_40.txt            8  3
# participant_3_trial_41.txt            9  3
# participant_3_trial_42.txt            8  3
# participant_3_trial_43.txt            2  3
# participant_3_trial_44.txt            5  3
# participant_3_trial_45.txt           10  3
# participant_3_trial_46.txt            5  3
# participant_3_trial_47.txt           21  3
# participant_3_trial_48.txt            6  3
# participant_3_trial_5.txt             0  3
# participant_3_trial_6.txt             0  3
# participant_3_trial_7.txt             0  3
# participant_3_trial_8.txt             0  3
# participant_3_trial_9.txt             0  3
#
#                                                                   inputPhrase  \
# file
# participant_1_trial_1.txt   all good boyd-delete-s f-delete-ded-delete-ser...
# participant_1_trial_10.txt  obligations must bd -delete--delete-e mey-dele...
# participant_1_trial_11.txt  a-delete-a picture is worth ,a-delete--delete-...
# participant_1_trial_12.txt  p.-delete-leade-delete--delete-se keep this co...
# participant_1_trial_13.txt  what a monl-delete-ket -delete--delete-y sers-...
# participant_1_trial_14.txt  motiba-delete--delete-vational semimz-delete--...
# participant_1_trial_15.txt  be persix-delete-stant to wu-delete-i n-delete...
# participant_1_trial_16.txt                        drove my chevy to the levee
# participant_1_trial_17.txt  the insulation ix-delete-s mo-delete--delete-n...
# participant_1_trial_18.txt  please take a bath tni-delete--delete-his mp-d...
# participant_1_trial_19.txt  he coi-delete-oled off after shd-delete-r-dele...
# participant_1_trial_2.txt   arguinb-delete-g with tb-delete-ne-delete--del...
# participant_1_trial_20.txt  taking the train is usually fadye-delete--dele...
# participant_1_trial_21.txt  ypu-delete--delete-pu-delete--delete-p-delete-...
# participant_1_trial_22.txt      teaching servicex -delete--delete-s will help
# participant_1_trial_23.txt     sent this by registeg-delete-rec-delete-d mail
# participant_1_trial_24.txt  we dine pu-delete--delete-pu-delete--delete-p-...
# participant_1_trial_25.txt                       my mother makes good cookies
# participant_1_trial_26.txt             sing theg-delete- gospel and the blues
# participant_1_trial_27.txt  experience ish-delete--delete-s hard to cp-del...
# participant_1_trial_28.txt                     go out for some pizza and beer
# participant_1_trial_29.txt                everybody looses in custody battles
# participant_1_trial_3.txt   he p,-delete-layec-delete-c-delete-d a li-dele...
# participant_1_trial_30.txt                     pay off a mortgage for a house
# participant_1_trial_31.txt  your presem-delete- n-delete--delete-ntation w...
# participant_1_trial_32.txt      the assault took six months-delete--delete-hs
# participant_1_trial_33.txt                dolphins leap high out of the water
# participant_1_trial_34.txt    medieval times were veru-delete--delete-ry hard
# participant_1_trial_35.txt        i like baroque and classical mux-delete-sic
# participant_1_trial_36.txt   there wi.-delete-ll be some fog tonign-delete-ht
# ...                                                                       ...
# participant_3_trial_26.txt  li,-delete-mited warrg-delete-abt-delete--dele...
# participant_3_trial_27.txt  wx-delete--delete-exwe-delete--delete-erciae-d...
# participant_3_trial_28.txt  these barracks arw bi-delete--delete--delete--...
# participant_3_trial_29.txt  people bliw -delete--delete--delete-ow their h...
# participant_3_trial_3.txt                       movie about a nutty professor
# participant_3_trial_30.txt  bank transactiom-delete-ns was not registee-de...
# participant_3_trial_31.txt  an airport ias -delete--delete--delete-s a ver...
# participant_3_trial_32.txt  wge-delete--delete-hw-delete-ere did u-delete-...
# participant_3_trial_33.txt  wga-delete--delete-g-delete-hat to do when tnd...
# participant_3_trial_34.txt  every apple dro-delete--delete--delete-from e ...
# participant_3_trial_35.txt  tge-delete--delete-he dow jones index has riae...
# participant_3_trial_36.txt  you e-delete-will loose yiy -delete--delete--d...
# participant_3_trial_37.txt  ec-delete-xcesc-delete--delete-ed the ma x-del...
# participant_3_trial_38.txt  prayer im -delete--delete-n s h-delete-c-delet...
# participant_3_trial_39.txt  interacyin-delete--delete--delete-tip-delete-o...
# participant_3_trial_4.txt                     the first time he tried to swim
# participant_3_trial_40.txt  the earlj-delete-y birdge-delete--delete- geys...
# participant_3_trial_41.txt  reala-delete--delete--delete-lations ate-delet...
# participant_3_trial_42.txt  s-delete-z-delete-a coupom-delete-n for a cre-...
# participant_3_trial_43.txt  dolphims-delete--delete-ns leap high out of th...
# participant_3_trial_44.txt  seasones -delete--delete-d golfers po-delete--...
# participant_3_trial_45.txt  a swcurit-delete--delete--delete--delete--dele...
# participant_3_trial_46.txt  parkinf-delete-g lots -delete--delete- is du-d...
# participant_3_trial_47.txt  a good rezpi-delete--delete--delete-spom-delet...
# participant_3_trial_48.txt  fall is my fa our-delete--delete--delete--dele...
# participant_3_trial_5.txt                     important for political parties
# participant_3_trial_6.txt                     reading week is just about here
# participant_3_trial_7.txt                       wear a crown with many jewels
# participant_3_trial_8.txt                      circumstances are unacceptable
# participant_3_trial_9.txt                      win first prize in the contest
#
#                                                        inputText  \
# file
# participant_1_trial_1.txt            all good boys deserve fudge
# participant_1_trial_10.txt         obligations must be met first
# participant_1_trial_11.txt         a picture is worth many words
# participant_1_trial_12.txt         please keep this confidential
# participant_1_trial_13.txt   what a monkey sees a monkey will do
# participant_1_trial_14.txt    motivational seminars make me sick
# participant_1_trial_15.txt         be persistant to win a strike
# participant_1_trial_16.txt           drove my chevy to the levee
# participant_1_trial_17.txt         the insulation is not working
# participant_1_trial_18.txt         please take a bath this month
# participant_1_trial_19.txt          he cooled off after she left
# participant_1_trial_2.txt        arguing with the boss is futile
# participant_1_trial_20.txt    taking the train is usually faster
# participant_1_trial_21.txt          you must make an appointment
# participant_1_trial_22.txt           teaching services will help
# participant_1_trial_23.txt          sent this by registered mail
# participant_1_trial_24.txt           we dine out on the weekends
# participant_1_trial_25.txt          my mother makes good cookies
# participant_1_trial_26.txt         sing the gospel and the blues
# participant_1_trial_27.txt         experience is hard to come by
# participant_1_trial_28.txt        go out for some pizza and beer
# participant_1_trial_29.txt   everybody looses in custody battles
# participant_1_trial_3.txt        he played a pimp in that  movie
# participant_1_trial_30.txt        pay off a mortgage for a house
# participant_1_trial_31.txt       your presentation was inspiring
# participant_1_trial_32.txt           the assault took six months
# participant_1_trial_33.txt   dolphins leap high out of the water
# participant_1_trial_34.txt         medieval times were very hard
# participant_1_trial_35.txt    i like baroque and classical music
# participant_1_trial_36.txt        there will be some fog tonight
# ...                                                          ...
# participant_3_trial_26.txt         limited warranty of two years
# participant_3_trial_27.txt         exercise is good for the mind
# participant_3_trial_28.txt         these barracks are big enough
# participant_3_trial_29.txt          people blow their horn a lot
# participant_3_trial_3.txt          movie about a nutty professor
# participant_3_trial_30.txt  bank transactions was not registered
# participant_3_trial_31.txt       an airport is a very busy place
# participant_3_trial_32.txt            where did you get that tie
# participant_3_trial_33.txt      what to do when the oil runs dry
# participant_3_trial_34.txt           every apple from every tree
# participant_3_trial_35.txt         the dow jones index has risen
# participant_3_trial_36.txt             you will loose your voice
# participant_3_trial_37.txt        exceed the maximum speed limit
# participant_3_trial_38.txt        prayer in schools offends some
# participant_3_trial_39.txt    interactions between men and women
# participant_3_trial_4.txt        the first time he tried to swim
# participant_3_trial_40.txt          the early bird gets the worm
# participant_3_trial_41.txt           relations are very strained
# participant_3_trial_42.txt            a coupon for a free sample
# participant_3_trial_43.txt   dolphins leap high out of the water
# participant_3_trial_44.txt        seasoned golfers love the game
# participant_3_trial_45.txt    a security force of eight thousand
# participant_3_trial_46.txt         parking lot is full of trucks
# participant_3_trial_47.txt       a good response to the question
# participant_3_trial_48.txt            fall is my favorite season
# participant_3_trial_5.txt        important for political parties
# participant_3_trial_6.txt        reading week is just about here
# participant_3_trial_7.txt          wear a crown with many jewels
# participant_3_trial_8.txt         circumstances are unacceptable
# participant_3_trial_9.txt         win first prize in the contest
#
#                             keyPressedTimes   scale  \
# file
# participant_1_trial_1.txt                33  0.2405
# participant_1_trial_10.txt               35  0.2405
# participant_1_trial_11.txt               49  0.2405
# participant_1_trial_12.txt               39  0.2405
# participant_1_trial_13.txt               59  0.2690
# participant_1_trial_14.txt               52  0.2690
# participant_1_trial_15.txt               43  0.2690
# participant_1_trial_16.txt               27  0.2690
# participant_1_trial_17.txt               35  0.2690
# participant_1_trial_18.txt               39  0.2690
# participant_1_trial_19.txt               38  0.2690
# participant_1_trial_2.txt                39  0.2405
# participant_1_trial_20.txt               40  0.2690
# participant_1_trial_21.txt               46  0.2690
# participant_1_trial_22.txt               31  0.2690
# participant_1_trial_23.txt               32  0.2690
# participant_1_trial_24.txt               65  0.2690
# participant_1_trial_25.txt               28  0.2405
# participant_1_trial_26.txt               31  0.2405
# participant_1_trial_27.txt               35  0.2405
# participant_1_trial_28.txt               30  0.2405
# participant_1_trial_29.txt               35  0.2405
# participant_1_trial_3.txt                49  0.2405
# participant_1_trial_30.txt               30  0.2405
# participant_1_trial_31.txt               39  0.2405
# participant_1_trial_32.txt               31  0.2405
# participant_1_trial_33.txt               35  0.2405
# participant_1_trial_34.txt               33  0.2405
# participant_1_trial_35.txt               36  0.2405
# participant_1_trial_36.txt               34  0.2405
# ...                                     ...     ...
# participant_3_trial_26.txt               37  0.2690
# participant_3_trial_27.txt               51  0.2690
# participant_3_trial_28.txt               37  0.2690
# participant_3_trial_29.txt               38  0.2690
# participant_3_trial_3.txt                29  0.2690
# participant_3_trial_30.txt               40  0.2690
# participant_3_trial_31.txt               39  0.2690
# participant_3_trial_32.txt               40  0.2690
# participant_3_trial_33.txt               42  0.2690
# participant_3_trial_34.txt               39  0.2690
# participant_3_trial_35.txt               45  0.2690
# participant_3_trial_36.txt               35  0.2690
# participant_3_trial_37.txt               48  0.2405
# participant_3_trial_38.txt               42  0.2405
# participant_3_trial_39.txt               50  0.2405
# participant_3_trial_4.txt                31  0.2690
# participant_3_trial_40.txt               44  0.2405
# participant_3_trial_41.txt               45  0.2405
# participant_3_trial_42.txt               42  0.2405
# participant_3_trial_43.txt               39  0.2405
# participant_3_trial_44.txt               40  0.2405
# participant_3_trial_45.txt               54  0.2405
# participant_3_trial_46.txt               39  0.2405
# participant_3_trial_47.txt               73  0.2405
# participant_3_trial_48.txt               38  0.2405
# participant_3_trial_5.txt                31  0.2690
# participant_3_trial_6.txt                31  0.2690
# participant_3_trial_7.txt                29  0.2690
# participant_3_trial_8.txt                30  0.2690
# participant_3_trial_9.txt                30  0.2690
#
#                                                    targetPhrase     time  \
# file
# participant_1_trial_1.txt           all good boys deserve fudge  22.7304
# participant_1_trial_10.txt        obligations must be met first  17.9416
# participant_1_trial_11.txt        a picture is worth many words  25.2109
# participant_1_trial_12.txt        please keep this confidential  22.4885
# participant_1_trial_13.txt  what a monkey sees a monkey will do  34.2924
# participant_1_trial_14.txt   motivational seminars make me sick  32.8041
# participant_1_trial_15.txt        be persistent to win a strike  22.6689
# participant_1_trial_16.txt          drove my chevy to the levee  15.1372
# participant_1_trial_17.txt        the insulation is not working  17.0355
# participant_1_trial_18.txt        please take a bath this month  19.2413
# participant_1_trial_19.txt         he cooled off after she left  21.2011
# participant_1_trial_2.txt       arguing with the boss is futile  23.8538
# participant_1_trial_20.txt   taking the train is usually faster  18.8354
# participant_1_trial_21.txt         you must make an appointment  23.3044
# participant_1_trial_22.txt          teaching services will help  14.9363
# participant_1_trial_23.txt         sent this by registered mail  14.2188
# participant_1_trial_24.txt          we dine out on the weekends  32.0989
# participant_1_trial_25.txt         my mother makes good cookies  31.6151
# participant_1_trial_26.txt        sing the gospel and the blues  30.5409
# participant_1_trial_27.txt        experience is hard to come by  34.2104
# participant_1_trial_28.txt       go out for some pizza and beer  28.6057
# participant_1_trial_29.txt  everybody looses in custody battles  37.6421
# participant_1_trial_3.txt        he played a pimp in that movie  30.8894
# participant_1_trial_30.txt       pay off a mortgage for a house  28.4335
# participant_1_trial_31.txt      your presentation was inspiring  37.6134
# participant_1_trial_32.txt          the assault took six months  28.3843
# participant_1_trial_33.txt  dolphins leap high out of the water  33.2100
# participant_1_trial_34.txt        medieval times were very hard  28.5196
# participant_1_trial_35.txt   i like baroque and classical music  35.8709
# participant_1_trial_36.txt       there will be some fog tonight  29.1592
# ...                                                         ...      ...
# participant_3_trial_26.txt        limited warranty of two years  23.5791
# participant_3_trial_27.txt        exercise is good for the mind  32.6319
# participant_3_trial_28.txt        these barracks are big enough  22.9969
# participant_3_trial_29.txt         people blow their horn a lot  25.8013
# participant_3_trial_3.txt         movie about a nutty professor  32.3531
# participant_3_trial_30.txt  bank transaction was not registered  27.6627
# participant_3_trial_31.txt      an airport is a very busy place  26.2441
# participant_3_trial_32.txt           where did you get that tie  24.2187
# participant_3_trial_33.txt     what to do when the oil runs dry  24.3212
# participant_3_trial_34.txt          every apple from every tree  22.4885
# participant_3_trial_35.txt        the dow jones index has risen  27.3593
# participant_3_trial_36.txt            you will loose your voice  27.1338
# participant_3_trial_37.txt       exceed the maximum speed limit  34.5835
# participant_3_trial_38.txt       prayer in schools offends some  27.6135
# participant_3_trial_39.txt   interactions between men and women  31.6725
# participant_3_trial_4.txt       the first time he tried to swim  33.5503
# participant_3_trial_40.txt         the early bird gets the worm  28.9501
# participant_3_trial_41.txt          relations are very strained  29.5118
# participant_3_trial_42.txt           a coupon for a free sample  27.0518
# participant_3_trial_43.txt  dolphins leap high out of the water  19.2659
# participant_3_trial_44.txt       seasoned golfers love the game  23.6406
# participant_3_trial_45.txt   a security force of eight thousand  29.0075
# participant_3_trial_46.txt        parking lot is full of trucks  21.3774
# participant_3_trial_47.txt      a good response to the question  39.5199
# participant_3_trial_48.txt           fall is my favorite season  19.8522
# participant_3_trial_5.txt       important for political parties  33.5216
# participant_3_trial_6.txt       reading week is just about here  34.4605
# participant_3_trial_7.txt         wear a crown with many jewels  31.2953
# participant_3_trial_8.txt        circumstances are unacceptable  34.9853
# participant_3_trial_9.txt        win first prize in the contest  36.2604
#
#                               type  screenSize  fuzzyRatio  correct  IF  \
# file
# participant_1_trial_1.txt   normal          38         100       27   3
# participant_1_trial_10.txt  normal          38         100       29   3
# participant_1_trial_11.txt  normal          38         100       29   4
# participant_1_trial_12.txt  normal          38         100       29   5
# participant_1_trial_13.txt  normal          42         100       35  10
# participant_1_trial_14.txt  normal          42         100       34   9
# participant_1_trial_15.txt  normal          42          97       28   6
# participant_1_trial_16.txt  normal          42         100       27   0
# participant_1_trial_17.txt  normal          42         100       29   3
# participant_1_trial_18.txt  normal          42         100       29   5
# participant_1_trial_19.txt  normal          42         100       28   4
# participant_1_trial_2.txt   normal          38         100       31   3
# participant_1_trial_20.txt  normal          42         100       34   3
# participant_1_trial_21.txt  normal          42         100       28   6
# participant_1_trial_22.txt  normal          42         100       27   2
# participant_1_trial_23.txt  normal          42         100       28   2
# participant_1_trial_24.txt  normal          42         100       27  12
# participant_1_trial_25.txt    zoom          38         100       28   0
# participant_1_trial_26.txt    zoom          38         100       29   1
# participant_1_trial_27.txt    zoom          38         100       29   3
# participant_1_trial_28.txt    zoom          38         100       30   0
# participant_1_trial_29.txt    zoom          38         100       35   0
# participant_1_trial_3.txt   normal          38          98       25   6
# participant_1_trial_30.txt    zoom          38         100       30   0
# participant_1_trial_31.txt    zoom          38         100       31   3
# participant_1_trial_32.txt    zoom          38         100       27   2
# participant_1_trial_33.txt    zoom          38         100       35   0
# participant_1_trial_34.txt    zoom          38         100       29   2
# participant_1_trial_35.txt    zoom          38         100       34   1
# participant_1_trial_36.txt    zoom          38         100       30   2
# ...                            ...         ...         ...      ...  ..
# participant_3_trial_26.txt  normal          42         100       29   4
# participant_3_trial_27.txt  normal          42         100       29  11
# participant_3_trial_28.txt  normal          42         100       29   4
# participant_3_trial_29.txt  normal          42         100       28   5
# participant_3_trial_3.txt     zoom          42         100       29   0
# participant_3_trial_30.txt  normal          42          99       16   1
# participant_3_trial_31.txt  normal          42         100       31   4
# participant_3_trial_32.txt  normal          42         100       26   6
# participant_3_trial_33.txt  normal          42         100       32   3
# participant_3_trial_34.txt  normal          42         100       27   6
# participant_3_trial_35.txt  normal          42         100       29   5
# participant_3_trial_36.txt  normal          42         100       25   5
# participant_3_trial_37.txt  normal          38         100       30   9
# participant_3_trial_38.txt  normal          38         100       30   4
# participant_3_trial_39.txt  normal          38         100       34   6
# participant_3_trial_4.txt     zoom          42         100       31   0
# participant_3_trial_40.txt  normal          38         100       28   6
# participant_3_trial_41.txt  normal          38         100       27   7
# participant_3_trial_42.txt  normal          38         100       26   7
# participant_3_trial_43.txt  normal          38         100       35   2
# participant_3_trial_44.txt  normal          38         100       30   5
# participant_3_trial_45.txt  normal          38         100       34  10
# participant_3_trial_46.txt  normal          38         100       29   5
# participant_3_trial_47.txt  normal          38         100       31  12
# participant_3_trial_48.txt  normal          38         100       26   6
# participant_3_trial_5.txt     zoom          42         100       31   0
# participant_3_trial_6.txt     zoom          42         100       31   0
# participant_3_trial_7.txt     zoom          42         100       29   0
# participant_3_trial_8.txt     zoom          42         100       30   0
# participant_3_trial_9.txt     zoom          42         100       30   0
#
#                             characters  INF  accuracy/time/char  \
# file
# participant_1_trial_1.txt           27    0            0.162941
# participant_1_trial_10.txt          29    0            0.192194
# participant_1_trial_11.txt          29    0            0.136777
# participant_1_trial_12.txt          29    0            0.153335
# participant_1_trial_13.txt          35    0            0.083317
# participant_1_trial_14.txt          34    0            0.089659
# participant_1_trial_15.txt          29    1            0.147551
# participant_1_trial_16.txt          27    0            0.244676
# participant_1_trial_17.txt          29    0            0.202417
# participant_1_trial_18.txt          29    0            0.179212
# participant_1_trial_19.txt          28    0            0.168455
# participant_1_trial_2.txt           31    0            0.135232
# participant_1_trial_20.txt          34    0            0.156152
# participant_1_trial_21.txt          28    0            0.153251
# participant_1_trial_22.txt          27    0            0.247967
# participant_1_trial_23.txt          28    0            0.251177
# participant_1_trial_24.txt          27    0            0.115384
# participant_1_trial_25.txt          28    0            0.112966
# participant_1_trial_26.txt          29    0            0.112907
# participant_1_trial_27.txt          29    0            0.100796
# participant_1_trial_28.txt          30    0            0.116527
# participant_1_trial_29.txt          35    0            0.075903
# participant_1_trial_3.txt           30    6            0.105754
# participant_1_trial_30.txt          30    0            0.117233
# participant_1_trial_31.txt          31    0            0.085762
# participant_1_trial_32.txt          27    0            0.130484
# participant_1_trial_33.txt          35    0            0.086033
# participant_1_trial_34.txt          29    0            0.120909
# participant_1_trial_35.txt          34    0            0.081993
# participant_1_trial_36.txt          30    0            0.114315
# ...                                ...  ...                 ...
# participant_3_trial_26.txt          29    0            0.146243
# participant_3_trial_27.txt          29    0            0.105672
# participant_3_trial_28.txt          29    0            0.149945
# participant_3_trial_29.txt          28    0            0.138420
# participant_3_trial_3.txt           29    0            0.106583
# participant_3_trial_30.txt          35   20            0.102252
# participant_3_trial_31.txt          31    0            0.122915
# participant_3_trial_32.txt          26    0            0.158809
# participant_3_trial_33.txt          32    0            0.128489
# participant_3_trial_34.txt          27    0            0.164693
# participant_3_trial_35.txt          29    0            0.126037
# participant_3_trial_36.txt          25    0            0.147418
# participant_3_trial_37.txt          30    0            0.096385
# participant_3_trial_38.txt          30    0            0.120714
# participant_3_trial_39.txt          34    0            0.092862
# participant_3_trial_4.txt           31    0            0.096148
# participant_3_trial_40.txt          28    0            0.123365
# participant_3_trial_41.txt          27    0            0.125499
# participant_3_trial_42.txt          26    0            0.142177
# participant_3_trial_43.txt          35    0            0.148301
# participant_3_trial_44.txt          30    0            0.141000
# participant_3_trial_45.txt          34    0            0.101394
# participant_3_trial_46.txt          29    0            0.161305
# participant_3_trial_47.txt          31    0            0.081625
# participant_3_trial_48.txt          26    0            0.193739
# participant_3_trial_5.txt           31    0            0.096231
# participant_3_trial_6.txt           31    0            0.093609
# participant_3_trial_7.txt           29    0            0.110185
# participant_3_trial_8.txt           30    0            0.095278
# participant_3_trial_9.txt           30    0            0.091928
#
#                             totalErrorRate
# file
# participant_1_trial_1.txt         0.100000
# participant_1_trial_10.txt        0.093750
# participant_1_trial_11.txt        0.121212
# participant_1_trial_12.txt        0.147059
# participant_1_trial_13.txt        0.222222
# participant_1_trial_14.txt        0.209302
# participant_1_trial_15.txt        0.200000
# participant_1_trial_16.txt        0.000000
# participant_1_trial_17.txt        0.093750
# participant_1_trial_18.txt        0.147059
# participant_1_trial_19.txt        0.125000
# participant_1_trial_2.txt         0.088235
# participant_1_trial_20.txt        0.081081
# participant_1_trial_21.txt        0.176471
# participant_1_trial_22.txt        0.068966
# participant_1_trial_23.txt        0.066667
# participant_1_trial_24.txt        0.307692
# participant_1_trial_25.txt        0.000000
# participant_1_trial_26.txt        0.033333
# participant_1_trial_27.txt        0.093750
# participant_1_trial_28.txt        0.000000
# participant_1_trial_29.txt        0.000000
# participant_1_trial_3.txt         0.324324
# participant_1_trial_30.txt        0.000000
# participant_1_trial_31.txt        0.088235
# participant_1_trial_32.txt        0.068966
# participant_1_trial_33.txt        0.000000
# participant_1_trial_34.txt        0.064516
# participant_1_trial_35.txt        0.028571
# participant_1_trial_36.txt        0.062500
# ...                                    ...
# participant_3_trial_26.txt        0.121212
# participant_3_trial_27.txt        0.275000
# participant_3_trial_28.txt        0.121212
# participant_3_trial_29.txt        0.151515
# participant_3_trial_3.txt         0.000000
# participant_3_trial_30.txt        0.567568
# participant_3_trial_31.txt        0.114286
# participant_3_trial_32.txt        0.187500
# participant_3_trial_33.txt        0.085714
# participant_3_trial_34.txt        0.181818
# participant_3_trial_35.txt        0.147059
# participant_3_trial_36.txt        0.166667
# participant_3_trial_37.txt        0.230769
# participant_3_trial_38.txt        0.117647
# participant_3_trial_39.txt        0.150000
# participant_3_trial_4.txt         0.000000
# participant_3_trial_40.txt        0.176471
# participant_3_trial_41.txt        0.205882
# participant_3_trial_42.txt        0.212121
# participant_3_trial_43.txt        0.054054
# participant_3_trial_44.txt        0.142857
# participant_3_trial_45.txt        0.227273
# participant_3_trial_46.txt        0.147059
# participant_3_trial_47.txt        0.279070
# participant_3_trial_48.txt        0.187500
# participant_3_trial_5.txt         0.000000
# participant_3_trial_6.txt         0.000000
# participant_3_trial_7.txt         0.000000
# participant_3_trial_8.txt         0.000000
# participant_3_trial_9.txt         0.000000
#
# [96 rows x 17 columns]

# %%
a2.rawData['time'].mean()
# Out:
# 29.502489583333332

# %%
a2.totalErrorPivot()
# Out:
# screenSize        38                  42
# type          normal      zoom    normal      zoom
# id
# 1           0.183525  0.036656  0.141517  0.042469
# 3           0.177559  0.036151  0.235188  0.002604

# %%
a2.rawData.pivot_table(index='id',
                       columns=["screenSize", 'type'], 
                       values=['keyPressedTimes', 'deleteTimes', 'time', 'totalErrorRate']
                      )
# Out:
#            deleteTimes                               keyPressedTimes  \
# screenSize          38                  42                        38
# type            normal      zoom    normal      zoom          normal
# id
# 1             5.583333  1.250000  6.333333  1.416667       40.583333
# 3             8.083333  1.333333  5.833333  0.083333       46.166667
#
#                                                   time                        \
# screenSize                    42                    38                    42
# type             zoom     normal       zoom     normal       zoom     normal
# id
# 1           33.083333  42.250000  33.166667  22.607400  31.983758  22.147858
# 3           35.666667  41.416667  30.750000  27.670558  40.225783  26.505475
#
#                       totalErrorRate
# screenSize                        38                  42
# type             zoom         normal      zoom    normal      zoom
# id
# 1           30.155158       0.183525  0.036656  0.141517  0.042469
# 3           34.723925       0.177559  0.036151  0.235188  0.002604

# %%
df.loc['participant_2_trial_5.txt'].targetPhrase
# Out:
# 'mom made her a turtleneck'

# %%
inputPhrase = 'ad-delete-for your informatiohns only'
inputText = 'for your informatiohns only'
targetPhrase = 'for your information only'

file = df.loc['participant_1_trial_2.txt']
inputPhrase = file.inputPhrase
inputText = file.inputText
targetPhrase = file.targetPhrase

print(inputPhrase)
print(inputText)
print(targetPhrase)


def getCorrect (targetPhrase, inputText):
    count = 0
    stop = min(len(targetPhrase), len(inputText))
    for i, char in enumerate(targetPhrase):
        if i == stop:
            break
        if char == inputText[i]:
            count += 1
#         print(char, inputText[i])
    return count   
        
getCorrect(targetPhrase,inputText)
# Out:
# no ec-delete-xchange wef-delete--delete--delete-without a bill
# no exchange without a bill
# no exchange without a bill
# 26

# %%
def getINF (targetPhrase,inputText):
    correct = getCorrect (targetPhrase, inputText)
    return len(targetPhrase) - correct

getINF (targetPhrase,inputText)
# Out:
# 0

# %%
def getIF (targetPhrase,inputPhrase):
    import re
    inputPhrase = inputPhrase.replace('-delete-', '<')
    deletes = re.findall(r'<+',inputPhrase) # all the block of deletes that have been entered ('<<', '<', '<<<')
    m = re.findall(r'([\w\s]*)<+([\w\s]*)',inputPhrase) # the characters before and after the delete
    indexes = [ i.start() for i in re.finditer(r'<+',inputPhrase)] # the indexes of all the delete blocks
    count = 0 # count of all the incorrect fixes
    for i, s in enumerate(m):
        error, replace = s
        length = len(deletes[i])
        priorDeletes = ''.join(deletes[0:i])
        index = indexes[i] - length - len(priorDeletes) -1
        replace = replace[:length]
        correctReplace = targetPhrase[index:index+length] 
        print(f'replace: [{replace}]\tcorrect: [{correctReplace}]')
        count += getCorrect(correctReplace, replace)
    return count


print(inputPhrase)
print(inputText)
print(targetPhrase)

getIF (targetPhrase,inputPhrase)
# Out:
# no ec-delete-xchange wef-delete--delete--delete-without a bill
# no exchange without a bill
# no exchange without a bill
# replace: [x]	correct: [e]
# replace: [wit]	correct: [wit]
# 3

# %%
def fuzzy (targetPhrase,inputPhrase):
    from fuzzywuzzy import fuzz
    from fuzzywuzzy import process
    return fuzz.ratio(targetPhrase,inputText)

fuzzy (targetPhrase,inputPhrase)
# Out:
# 100

# %%
a2.getIF('the quick brown','thw quick<<<<<<<e quick brown')
# Out:
# thw quick<<<<<<<e quick brown
# the quick brown
# replace: [e quick]	correct: [e quick]
# Count: 7
# 7
