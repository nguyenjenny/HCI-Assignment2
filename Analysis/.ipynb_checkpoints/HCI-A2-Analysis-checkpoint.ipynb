# %%
class AnalysisHCI:

    def __init__(self, directory):
        # print('Make sure the directory has forward slashes')
        import os
        import pandas as pd
        self.directory = directory
        self.fileNameDF = self.FileNameDF()
        self.rawData = self.RawData()
        self.ProcessData()
        os.chdir(directory)
        
    def FileNameDF(self):
        import pandas as pd
        import numpy as np
        import glob
        self.fileNameDF = pd.DataFrame(columns=['file'])
        self.fileNameDF['file'] = glob.glob('participant_*')  
        self.fileNameDF.sort_values(by=['file'], inplace=True)
        return  self.fileNameDF
    def RawData(self):
        import pandas as pd
        self.FileNameDF()
        self.rawData = pd.DataFrame()
        for file in self.fileNameDF['file']:
            f = open(file, "r")
            j = f.readline()
            f.close()
            df = pd.DataFrame(eval(f'[{j}]'))
            df['file'] = file
            self.rawData = pd.concat([self.rawData, df], axis=0)
        self.rawData.set_index('file', inplace=True)
        self.rawData['screenSize'] = self.rawData['scale'].map(lambda x: "38 mm" if x == 0.2405 else "42 mm" )
        return self.rawData
    def Fuzzy (self, targetPhrase,inputText):    
        from fuzzywuzzy import fuzz
        from fuzzywuzzy import process
        return fuzz.ratio(targetPhrase,inputText)
    def getCorrect (self, targetPhrase, inputText):
        count = 0
        stop = min(len(targetPhrase), len(inputText))
        for i, char in enumerate(targetPhrase):
            if i == stop:
                break
            if char == inputText[i]:
                count += 1
        return count  
    def getIF (self, targetPhrase,inputPhrase):
        import re
        inputPhrase = inputPhrase.replace('-delete-', '<')
        deletes = re.findall(r'<+',inputPhrase) # all the block of deletes that have been entered ('<<', '<', '<<<')
        m = re.findall(r'([\w\s]*)<+([\w\s]*)',inputPhrase) # the characters before and after the delete
        indexes = [ i.start() for i in re.finditer(r'<+',inputPhrase)] # the indexes of all the delete blocks
        count = 0 # count of all the incorrect fixes
        print(inputPhrase)
        print(targetPhrase)
        for i, s in enumerate(m):
            error, replace = s
            length = len(deletes[i])
#             priorDeletes = 0 if len(''.join(deletes[0:i])) == 0 else len(''.join(deletes[0:i])) + 1
            priorDeletes = len(''.join(deletes[0:i]))*2
            index = indexes[i] - length - priorDeletes
            replace = replace[:length]
            correctReplace = targetPhrase[index:index+length] 
#             print(f'replace: [{replace}]\tcorrect: [{correctReplace}]')
            count += self.getCorrect(correctReplace, replace)
            print(f'replace: [{replace}]\tcorrect: [{correctReplace}]')
        print(f'Count: {count}\n')
        return count

    def ProcessData (self):
        from fuzzywuzzy import fuzz
        from fuzzywuzzy import process
        self.RawData()
        fuzzyResult = []
        correctResult = []
        ifResult = []
        for f in self.rawData.index:
            print(f)
            file = self.rawData.loc[f]
            inputPhrase = file.inputPhrase
            inputText = file.inputText
            targetPhrase = file.targetPhrase
            fuzzyResult.append(fuzz.ratio(targetPhrase,inputText))
            correctResult.append(self.getCorrect(targetPhrase, inputText))
            ifResult.append(self.getIF(targetPhrase,inputPhrase))
        self.rawData['fuzzyRatio'] = fuzzyResult
        self.rawData['correct'] = correctResult
        self.rawData['IF'] = ifResult
        self.rawData['characters'] =  self.rawData['targetPhrase'].map(lambda x: len(x))
        self.rawData['INF'] = self.rawData['keyPressedTimes'] -  self.rawData['correct'] - 2* self.rawData['deleteTimes']
        self.rawData['accuracy/time/char'] = self.rawData['fuzzyRatio']/self.rawData['time']/self.rawData['characters']
        self.rawData['totalErrorRate'] = (self.rawData['INF'] + self.rawData['IF'])/(self.rawData['correct'] +self.rawData['INF'] + self.rawData['IF']) * 100
        return self.rawData
    def totalErrorPivot (self):
        return self.rawData.pivot_table( index='id', columns= ["screenSize", 'type'], values='totalErrorRate')

# %%
directory = '/Users/jenny/Documents/School/IBBME/CSC2514/CSC2514-Assignments/HCI-Assignment2/Analysis/Data/ParticipantData'
a2 = AnalysisHCI(directory)
# Out:
# participant_1_trial_1.txt
# all good boyd<s f<ded<serve fudge
# all good boys deserve fudge
# replace: [s]	correct: [s]
# replace: [d]	correct: [d]
# replace: [s]	correct: [s]
# Count: 3
#
# participant_1_trial_10.txt
# obligations must bd <<e mey<t first
# obligations must be met first
# replace: [e ]	correct: [e ]
# replace: [t]	correct: [t]
# Count: 3
#
# participant_1_trial_11.txt
# a<a picture is worth ,a<<,a< <<<m< mamy<<ny words
# a picture is worth many words
# replace: [a]	correct: [a]
# replace: []	correct: [ma]
# replace: [ ]	correct: [a]
# replace: [m]	correct: [ ma]
# replace: [ ]	correct: [ ]
# replace: [ny]	correct: [ny]
# Count: 4
#
# participant_1_trial_12.txt
# p.<leade<<se keep this co n<<nfidential
# please keep this confidential
# replace: [l]	correct: [l]
# replace: [se]	correct: [se]
# replace: [nf]	correct: [nf]
# Count: 5
#
# participant_1_trial_13.txt
# what a monl<ket <<y sers<<es a mo m<<nkey wil.<<..<<ll dp<o
# what a monkey sees a monkey will do
# replace: [k]	correct: [k]
# replace: [y ]	correct: [y ]
# replace: [es]	correct: [es]
# replace: [nk]	correct: [nk]
# replace: []	correct: [ll]
# replace: [ll]	correct: [ll]
# replace: [o]	correct: [o]
# Count: 10
#
# participant_1_trial_14.txt
# motiba<<vational semimz<<narz<s mame<<ke mr<e so<ick
# motivational seminars make me sick
# replace: [va]	correct: [va]
# replace: [na]	correct: [na]
# replace: [s]	correct: [s]
# replace: [ke]	correct: [ke]
# replace: [e]	correct: [e]
# replace: [i]	correct: [i]
# Count: 9
#
# participant_1_trial_15.txt
# be persix<stant to wu<i n<<n a stro<uk<<ike
# be persistent to win a strike
# replace: [s]	correct: [s]
# replace: [i]	correct: [i]
# replace: [n ]	correct: [n ]
# replace: [u]	correct: [i]
# replace: [ik]	correct: [ik]
# Count: 6
#
# participant_1_trial_16.txt
# drove my chevy to the levee
# drove my chevy to the levee
# Count: 0
#
# participant_1_trial_17.txt
# the insulation ix<s mo<<not working
# the insulation is not working
# replace: [s]	correct: [s]
# replace: [no]	correct: [no]
# Count: 3
#
# participant_1_trial_18.txt
# please take a bath tni<<his mp<ontn<<th
# please take a bath this month
# replace: [hi]	correct: [hi]
# replace: [o]	correct: [o]
# replace: [th]	correct: [th]
# Count: 5
#
# participant_1_trial_19.txt
# he coi<oled off after shd<r<e lrg<<eft
# he cooled off after she left
# replace: [o]	correct: [o]
# replace: [r]	correct: [e]
# replace: [e]	correct: [e]
# replace: [ef]	correct: [ef]
# Count: 4
#
# participant_1_trial_2.txt
# arguinb<g with tb<ne<<he boss is futile
# arguing with the boss is futile
# replace: [g]	correct: [g]
# replace: [n]	correct: [h]
# replace: [he]	correct: [he]
# Count: 3
#
# participant_1_trial_20.txt
# taking the train is usually fadye<<<ster
# taking the train is usually faster
# replace: [ste]	correct: [ste]
# Count: 3
#
# participant_1_trial_21.txt
# ypu<<pu<<p<ou ,u<<must mz<ake an appointmem<nt
# you must make an appointment
# replace: [pu]	correct: [ou]
# replace: [p]	correct: [ou]
# replace: [o]	correct: [o]
# replace: [mu]	correct: [mu]
# replace: [a]	correct: [a]
# replace: [n]	correct: [n]
# Count: 6
#
# participant_1_trial_22.txt
# teaching servicex <<s will help
# teaching services will help
# replace: [s ]	correct: [s ]
# Count: 2
#
# participant_1_trial_23.txt
# sent this by registeg<rec<d mail
# sent this by registered mail
# replace: [r]	correct: [r]
# replace: [d]	correct: [d]
# Count: 2
#
# participant_1_trial_24.txt
# we dine pu<<pu<<p<out pn<<on tjr<<nr<<he wr<eeld<<kenfs<<fs<<dx<s
# we dine out on the weekends
# replace: [pu]	correct: [ou]
# replace: [p]	correct: [ou]
# replace: [o]	correct: [o]
# replace: [on]	correct: [on]
# replace: [nr]	correct: [he]
# replace: [he]	correct: [he]
# replace: [e]	correct: [e]
# replace: [ke]	correct: [ke]
# replace: [fs]	correct: [ds]
# replace: [dx]	correct: [ds]
# replace: [s]	correct: [s]
# Count: 12
#
# participant_1_trial_25.txt
# my mother makes good cookies
# my mother makes good cookies
# Count: 0
#
# participant_1_trial_26.txt
# sing theg< gospel and the blues
# sing the gospel and the blues
# replace: [ ]	correct: [ ]
# Count: 1
#
# participant_1_trial_27.txt
# experience ish<<s hard to cp<ome by
# experience is hard to come by
# replace: [s ]	correct: [s ]
# replace: [o]	correct: [o]
# Count: 3
#
# participant_1_trial_28.txt
# go out for some pizza and beer
# go out for some pizza and beer
# Count: 0
#
# participant_1_trial_29.txt
# everybody looses in custody battles
# everybody looses in custody battles
# Count: 0
#
# participant_1_trial_3.txt
# he p,<layec<c<d a li<<pimp i  <n<<n that  o<movie
# he played a pimp in that movie
# replace: [l]	correct: [l]
# replace: [c]	correct: [d]
# replace: [d]	correct: [d]
# replace: [pi]	correct: [pi]
# replace: [n]	correct: [ ]
# replace: [n ]	correct: [n ]
# replace: [m]	correct: [o]
# Count: 6
#
# participant_1_trial_30.txt
# pay off a mortgage for a house
# pay off a mortgage for a house
# Count: 0
#
# participant_1_trial_31.txt
# your presem< n<<ntation was inspirinf<g
# your presentation was inspiring
# replace: [ ]	correct: [n]
# replace: [nt]	correct: [nt]
# replace: [g]	correct: [g]
# Count: 3
#
# participant_1_trial_32.txt
# the assault took six months<<hs
# the assault took six months
# replace: [hs]	correct: [hs]
# Count: 2
#
# participant_1_trial_33.txt
# dolphins leap high out of the water
# dolphins leap high out of the water
# Count: 0
#
# participant_1_trial_34.txt
# medieval times were veru<<ry hard
# medieval times were very hard
# replace: [ry]	correct: [ry]
# Count: 2
#
# participant_1_trial_35.txt
# i like baroque and classical mux<sic
# i like baroque and classical music
# replace: [s]	correct: [s]
# Count: 1
#
# participant_1_trial_36.txt
# there wi.<ll be some fog tonign<ht
# there will be some fog tonight
# replace: [l]	correct: [l]
# replace: [h]	correct: [h]
# Count: 2
#
# participant_1_trial_37.txt
# the rationz<ale behind the desic<<<cision
# the rationale behind the decision
# replace: [a]	correct: [a]
# replace: [cis]	correct: [cis]
# Count: 4
#
# participant_1_trial_38.txt
# well connectec<d with pr<eople
# well connected with people
# replace: [d]	correct: [d]
# replace: [e]	correct: [e]
# Count: 2
#
# participant_1_trial_39.txt
# where did you get such a silly idea
# where did you get such a silly idea
# Count: 0
#
# participant_1_trial_4.txt
# all together in one ni<<big pi.<le
# all together in one big pile
# replace: [bi]	correct: [bi]
# replace: [l]	correct: [l]
# Count: 3
#
# participant_1_trial_40.txt
# win first prize in the contest
# win first prize in the contest
# Count: 0
#
# participant_1_trial_41.txt
# i watched bo<lazing saddles
# i watched blazing saddles
# replace: [l]	correct: [l]
# Count: 1
#
# participant_1_trial_42.txt
# vi<ote according to y <our conscience
# vote according to your conscience
# replace: [o]	correct: [o]
# replace: [o]	correct: [o]
# Count: 2
#
# participant_1_trial_43.txt
# neither ay< borrower nor a lendr<er v<be
# neither a borrower nor a lender be
# replace: [ ]	correct: [ ]
# replace: [e]	correct: [e]
# replace: [b]	correct: [b]
# Count: 3
#
# participant_1_trial_44.txt
# why doy< you<<ou ask silly questions
# why do you ask silly questions
# replace: [ ]	correct: [ ]
# replace: [ou]	correct: [ou]
# Count: 3
#
# participant_1_trial_45.txt
# frequently asked questions
# frequently asked questions
# Count: 0
#
# participant_1_trial_46.txt
# electric cars need big fuel cells
# electric cars need big fuel cells
# Count: 0
#
# participant_1_trial_47.txt
# we are subjects and must obey
# we are subjects and must obey
# Count: 0
#
# participant_1_trial_48.txt
# i spi.l<<lled coffee on the carpet
# i spilled coffee on the carpet
# replace: [ll]	correct: [ll]
# Count: 2
#
# participant_1_trial_5.txt
# histof<ro<ic  e<meetinv <<g without a rex<sult
# historic meeting without a result
# replace: [r]	correct: [r]
# replace: [i]	correct: [i]
# replace: [m]	correct: [e]
# replace: [g ]	correct: [ w]
# replace: [s]	correct: [u]
# Count: 2
#
# participant_1_trial_6.txt
# a good respo s<<nxe<<se to gn<<the quext<<stjo<<iom<n
# a good response to the question
# replace: [nx]	correct: [ns]
# replace: [se]	correct: [se]
# replace: [th]	correct: [th]
# replace: [st]	correct: [st]
# replace: [io]	correct: [io]
# replace: [n]	correct: [n]
# Count: 10
#
# participant_1_trial_7.txt
# gas<b<s bills are sent monthly
# gas bills are sent monthly
# replace: [b]	correct: [s]
# replace: [s]	correct: [s]
# Count: 1
#
# participant_1_trial_8.txt
# pib<<u b<<blic trz<ansit ix<s much gz<<g<fad<ster
# public transit is much faster
# replace: [u ]	correct: [ub]
# replace: [bl]	correct: [bl]
# replace: [a]	correct: [a]
# replace: [s]	correct: [s]
# replace: [g]	correct: [fa]
# replace: [f]	correct: [f]
# replace: [s]	correct: [s]
# Count: 7
#
# participant_1_trial_9.txt
# pae<rking lot is full of trucks
# parking lot is full of trucks
# replace: [r]	correct: [r]
# Count: 1
#
# participant_2_trial_1.txt
# take <<<<<impotamt<<<<rtant for pilitica.<<<<<<<<i,i<<<i<o.<litu<ical parties
# important for political parties
# replace: [impot]	correct: [impor]
# replace: [rtan]	correct: [rtan]
# replace: [i]	correct: [olitical]
# replace: [i]	correct: [oli]
# replace: [o]	correct: [o]
# replace: [l]	correct: [l]
# replace: [i]	correct: [i]
# Count: 11
#
# participant_2_trial_10.txt
# tell a lie and your nise <<<<ose will grow
# tell a lie and your nose will grow
# replace: [ose ]	correct: [ose ]
# Count: 4
#
# participant_2_trial_11.txt
# recrangyl<<<<<<tanf<gular objwcta<<<<<jects<havw<<<<s hq<ave four sidea<s
# rectangular objects have four sides
# replace: [tanf]	correct: [tangul]
# replace: [g]	correct: [g]
# replace: [jects]	correct: [jects]
# replace: [h]	correct: [s]
# replace: [s hq]	correct: [s ha]
# replace: [a]	correct: [a]
# replace: [s]	correct: [s]
# Count: 14
#
# participant_2_trial_12.txt
# i toik<<ok the river<<<<k<over fe<<fe<rom the sg<hop
# i took the rover from the shop
# replace: [ok]	correct: [ok]
# replace: [k]	correct: [over]
# replace: [o]	correct: [o]
# replace: [fe]	correct: [fr]
# replace: [r]	correct: [r]
# replace: [h]	correct: [h]
# Count: 6
#
# participant_2_trial_13.txt
# valif<s<d until the end of the year
# valid until the end of the year
# replace: [s]	correct: [d]
# replace: [d]	correct: [d]
# Count: 1
#
# participant_2_trial_14.txt
# pay off z<an< mortgage for a house
# pay off a mortgage for a house
# replace: [a]	correct: [a]
# replace: [ ]	correct: [ ]
# Count: 2
#
# participant_2_trial_15.txt
# presidents drive expensive cars
# presidents drive expensive cars
# Count: 0
#
# participant_2_trial_16.txt
# arguing with theboss is futile
# arguing with the boss is futile
# Count: 0
#
# participant_2_trial_17.txt
# dolphins leapb< high out of the water
# dolphins leap high out of the water
# replace: [ ]	correct: [ ]
# Count: 1
#
# participant_2_trial_18.txt
# rapidly running short k<on words
# rapidly running short on words
# replace: [o]	correct: [o]
# Count: 1
#
# participant_2_trial_19.txt
# vote according to your conscience
# vote according to your conscience
# Count: 0
#
# participant_2_trial_2.txt
# you muzt <<<st makw<e<e am <<n alpiunt<<<<<<plo<<pointmenr<t
# you must make an appointment
# replace: [st ]	correct: [st ]
# replace: [e]	correct: [e]
# replace: [e]	correct: [e]
# replace: [n ]	correct: [n ]
# replace: [plo]	correct: [ppoint]
# replace: [po]	correct: [po]
# replace: [t]	correct: [t]
# Count: 12
#
# participant_2_trial_20.txt
# i am a.<llergict< to bes<<ees and peanuts
# i am allergic to bees and peanuts
# replace: [l]	correct: [l]
# replace: [ ]	correct: [ ]
# replace: [ee]	correct: [ee]
# Count: 4
#
# participant_2_trial_21.txt
# interesting observationw< was made
# interesting observation was made
# replace: [ ]	correct: [ ]
# Count: 1
#
# participant_2_trial_22.txt
# taking the train is uss<ually faster
# taking the train is usually faster
# replace: [u]	correct: [u]
# Count: 1
#
# participant_2_trial_23.txt
# the pickw<et line gives me the chills
# the picket line gives me the chills
# replace: [e]	correct: [e]
# Count: 1
#
# participant_2_trial_24.txt
# the chancellor was very boring
# the chancellor was very boring
# Count: 0
#
# participant_2_trial_25.txt
# sg<hae<rp cheese kwe<<eeps rhe<<<the mins<d sharp
# sharp cheese keeps the mind sharp
# replace: [h]	correct: [h]
# replace: [r]	correct: [r]
# replace: [ee]	correct: [ee]
# replace: [the]	correct: [the]
# replace: [d]	correct: [d]
# Count: 8
#
# participant_2_trial_26.txt
# rhe<<<the musiv<c is better tham <<n t <<it sounds
# the music is better than it sounds
# replace: [the]	correct: [the]
# replace: [c]	correct: [c]
# replace: [n ]	correct: [n ]
# replace: [it]	correct: [it]
# Count: 8
#
# participant_2_trial_27.txt
# our bk<<<h << househe<<keeper does q<a thorough jon<b
# our housekeeper does a thorough job
# replace: [h ]	correct: [ ho]
# replace: [ h]	correct: [ h]
# replace: [ke]	correct: [ke]
# replace: [a]	correct: [a]
# replace: [b]	correct: [b]
# Count: 6
#
# participant_2_trial_28.txt
# the postal serbo<<ve<ice is vwry slow<<<<<<<<ert<y s.ow<<<,oc <<<<low
# the postal service is very slow
# replace: [ve]	correct: [vi]
# replace: [i]	correct: [i]
# replace: [ert]	correct: [ery slow]
# replace: [y]	correct: [y]
# replace: []	correct: [low]
# replace: [low]	correct: [low]
# Count: 8
#
# participant_2_trial_29.txt
# qui m <<<ck tne<<here<e is someo e<<nw<e kbo<<nocku<<king
# quick there is someone knocking
# replace: [ck ]	correct: [ck ]
# replace: [he]	correct: [he]
# replace: [e]	correct: [e]
# replace: [nw]	correct: [ne]
# replace: [e]	correct: [e]
# replace: [no]	correct: [no]
# replace: [ki]	correct: [ki]
# Count: 12
#
# participant_2_trial_3.txt
# xes<<<dea<ste<ructiin<<on od <c<<<of tne<<<h<the rai n<<n forest
# destruction of the rain forest
# replace: [dea]	correct: [des]
# replace: [s]	correct: [s]
# replace: [r]	correct: [r]
# replace: [on]	correct: [on]
# replace: [c]	correct: [ ]
# replace: [of ]	correct: [of ]
# replace: [h]	correct: [the]
# replace: [t]	correct: [t]
# replace: [n ]	correct: [n ]
# Count: 12
#
# participant_2_trial_30.txt
# well connected with peip.<<<ople
# well connected with people
# replace: [opl]	correct: [opl]
# Count: 3
#
# participant_2_trial_31.txt
# onw <<e of the poorest nq<atio e<<ns
# one of the poorest nations
# replace: [e ]	correct: [e ]
# replace: [a]	correct: [a]
# replace: [ns]	correct: [ns]
# Count: 5
#
# participant_2_trial_32.txt
# the cream risea<s to tje <<<he top
# the cream rises to the top
# replace: [s]	correct: [s]
# replace: [he ]	correct: [he ]
# Count: 4
#
# participant_2_trial_33.txt
# the locqt<<atuin<<<iom<n of the cri,e<<me
# the location of the crime
# replace: [at]	correct: [at]
# replace: [iom]	correct: [ion]
# replace: [n]	correct: [n]
# replace: [me]	correct: [me]
# Count: 7
#
# participant_2_trial_34.txt
# we better investiyq<<gq<atw<e thiw<s
# we better investigate this
# replace: [gq]	correct: [ga]
# replace: [a]	correct: [a]
# replace: [e]	correct: [e]
# replace: [s]	correct: [s]
# Count: 4
#
# participant_2_trial_35.txt
# tje<<he stock ev<xchqn< <<qn<<q<angw<e<e dippef<d
# the stock exchange dipped
# replace: [he]	correct: [he]
# replace: [x]	correct: [x]
# replace: [ ]	correct: [n]
# replace: [qn]	correct: [an]
# replace: [q]	correct: [an]
# replace: [a]	correct: [a]
# replace: [e]	correct: [e]
# replace: [e]	correct: [e]
# replace: [d]	correct: [d]
# Count: 8
#
# participant_2_trial_36.txt
# cqn <<<qnc  <<<<<an wr<e .p<<p,q<<lay carxs<<ds tonigbt<<<gnt<<ht
# can we play cards tonight
# replace: [qnc]	correct: [an ]
# replace: [an wr]	correct: [an we]
# replace: [e]	correct: [e]
# replace: [p]	correct: [pl]
# replace: [la]	correct: [la]
# replace: [ds]	correct: [ds]
# replace: [gnt]	correct: [ght]
# replace: [ht]	correct: [ht]
# Count: 15
#
# participant_2_trial_37.txt
# your presentation was inspiring
# your presentation was inspiring
# Count: 0
#
# participant_2_trial_38.txt
# find a nearby parking spot
# find a nearby parking spot
# Count: 0
#
# participant_2_trial_39.txt
# do you like y<to go camping
# do you like to go camping
# replace: [t]	correct: [t]
# Count: 1
#
# participant_2_trial_4.txt
# thia<s learh<<ther jacket is too warm
# this leather jacket is too warm
# replace: [s]	correct: [s]
# replace: [th]	correct: [th]
# Count: 3
#
# participant_2_trial_40.txt
# the most beautiful suna<set
# the most beautiful sunset
# replace: [s]	correct: [s]
# Count: 1
#
# participant_2_trial_41.txt
# neither a borrower nor z<< a lender be
# neither a borrower nor a lender be
# replace: [ a]	correct: [ a]
# Count: 2
#
# participant_2_trial_42.txt
# companis<es announce a merger
# companies announce a merger
# replace: [e]	correct: [e]
# Count: 1
#
# participant_2_trial_43.txt
# electric cars need big fuel cells
# electric cars need big fuel cells
# Count: 0
#
# participant_2_trial_44.txt
# the food at this restaurant
# the food at this restaurant
# Count: 0
#
# participant_2_trial_45.txt
# if you were not stupid<<<<<o stupid
# if you were not so stupid
# replace: [o stu]	correct: [o stu]
# Count: 5
#
# participant_2_trial_46.txt
# the assault took six months
# the assault took six months
# Count: 0
#
# participant_2_trial_47.txt
# a security force of eight thoua<sand
# a security force of eight thousand
# replace: [s]	correct: [s]
# Count: 1
#
# participant_2_trial_48.txt
# a big scratch on the tabletop
# a big scratch on the tabletop
# Count: 0
#
# participant_2_trial_5.txt
# spraq<wlun<<ing subdivisiom< s<<ns are bad
# sprawling subdivisions are bad
# replace: [w]	correct: [w]
# replace: [in]	correct: [in]
# replace: [ ]	correct: [n]
# replace: [ns]	correct: [ns]
# Count: 5
#
# participant_2_trial_6.txt
# if a for<<irst you di<o nit<<ot succeed
# if at first you do not succeed
# replace: [ir]	correct: [fi]
# replace: [o]	correct: [d]
# replace: [ot]	correct: [no]
# Count: 0
#
# participant_2_trial_7.txt
# my prefwr<<<fe <red<<ded<<<red trear<t is chocolatw<e
# my preferred treat is chocolate
# replace: [fe ]	correct: [fer]
# replace: [r]	correct: [r]
# replace: [de]	correct: [re]
# replace: [red]	correct: [red]
# replace: [t]	correct: [t]
# replace: [e]	correct: [e]
# Count: 9
#
# participant_2_trial_8.txt
# a good question<<<<<<<<respinze<<<<onse to the quezr<<<estion
# a good response to the question
# replace: [respinze]	correct: [response]
# replace: [onse]	correct: [onse]
# replace: [est]	correct: [est]
# Count: 13
#
# participant_2_trial_9.txt
# nevwr<<er mix religio  <  <n<<n<<n anx<d pilitica<<<<<<<olitics
# never mix religion and politics
# replace: [er]	correct: [er]
# replace: [ ]	correct: [ ]
# replace: [n]	correct: [a]
# replace: [n]	correct: [ a]
# replace: [n ]	correct: [n ]
# replace: [d]	correct: [d]
# replace: [olitics]	correct: [olitics]
# Count: 13
#
# participant_3_trial_1.txt
# the second largest country
# the second largest country
# Count: 0
#
# participant_3_trial_10.txt
# my preferred treat iss< chocolate
# my preferred treat is chocolate
# replace: [ ]	correct: [ ]
# Count: 1
#
# participant_3_trial_11.txt
# the presidential suite is very busy
# the presidential suite is very busy
# Count: 0
#
# participant_3_trial_12.txt
# one hour is allotted for questions
# one hour is allotted for questions
# Count: 0
#
# participant_3_trial_13.txt
# ta<<every saturday he folds the laundry
# every saturday he folds the laundry
# replace: [ev]	correct: [ev]
# Count: 2
#
# participant_3_trial_14.txt
# everybody looses in custody battles
# everybody looses in custody battles
# Count: 0
#
# participant_3_trial_15.txt
# players mustk< know all the rules
# players must know all the rules
# replace: [ ]	correct: [ ]
# Count: 1
#
# participant_3_trial_16.txt
# y<it< took the rover from the shop
# i took the rover from the shop
# replace: [i]	correct: [i]
# replace: [ ]	correct: [ ]
# Count: 2
#
# participant_3_trial_17.txt
# taking the train is usually faster
# taking the train is usually faster
# Count: 0
#
# participant_3_trial_18.txt
# the cat has a pleasent temperament
# the cat has a pleasant temperament
# Count: 0
#
# participant_3_trial_19.txt
# so you think you s<deserve a raise
# so you think you deserve a raise
# replace: [d]	correct: [d]
# Count: 1
#
# participant_3_trial_2.txt
# there will be some fog tonight
# there will be some fog tonight
# Count: 0
#
# participant_3_trial_20.txt
# our housekeepet<r does a thorough job
# our housekeeper does a thorough job
# replace: [r]	correct: [r]
# Count: 1
#
# participant_3_trial_21.txt
# arguing with the boss is futile
# arguing with the boss is futile
# Count: 0
#
# participant_3_trial_22.txt
# rapidly running short on words
# rapidly running short on words
# Count: 0
#
# participant_3_trial_23.txt
# at<t< tumor is ok provided it is benign
# a tumor is ok provided it is benign
# replace: [t]	correct: [ ]
# replace: [ ]	correct: [ ]
# Count: 1
#
# participant_3_trial_24.txt
# neother<<<<<<either a borrower nor a lender bw<e
# neither a borrower nor a lender be
# replace: [either]	correct: [either]
# replace: [e]	correct: [e]
# Count: 7
#
# participant_3_trial_25.txt
# thh<e pen is  ightiet<<<<<<< mif<ghtier than the sword
# the pen is mightier than the sword
# replace: [e]	correct: [e]
# replace: [ mif]	correct: [ightier]
# replace: [g]	correct: [t]
# Count: 1
#
# participant_3_trial_26.txt
# li,<mited warrg<abt<<nty of two years
# limited warranty of two years
# replace: [m]	correct: [m]
# replace: [a]	correct: [a]
# replace: [nt]	correct: [nt]
# Count: 4
#
# participant_3_trial_27.txt
# wx<<exwe<<erciae<<se ia <<s good for tge<<he minx<d
# exercise is good for the mind
# replace: [ex]	correct: [ex]
# replace: [er]	correct: [er]
# replace: [se]	correct: [se]
# replace: [s ]	correct: [s ]
# replace: [he]	correct: [he]
# replace: [d]	correct: [d]
# Count: 11
#
# participant_3_trial_28.txt
# these barracks arw bi<<<<e big enough
# these barracks are big enough
# replace: [e bi]	correct: [e bi]
# Count: 4
#
# participant_3_trial_29.txt
# people bliw <<<ow their horn a ,o<<lot
# people blow their horn a lot
# replace: [ow ]	correct: [ow ]
# replace: [lo]	correct: [lo]
# Count: 5
#
# participant_3_trial_3.txt
# movie about a nutty professor
# movie about a nutty professor
# Count: 0
#
# participant_3_trial_30.txt
# bank transactiom<ns was not registee<red
# bank transaction was not registered
# replace: [n]	correct: [n]
# replace: [r]	correct: [e]
# Count: 1
#
# participant_3_trial_31.txt
# an airport ias <<<s a very busy pk<lace
# an airport is a very busy place
# replace: [s a]	correct: [s a]
# replace: [l]	correct: [l]
# Count: 4
#
# participant_3_trial_32.txt
# wge<<hw<ere did u<you bey<<<get that tie
# where did you get that tie
# replace: [hw]	correct: [he]
# replace: [e]	correct: [e]
# replace: [y]	correct: [y]
# replace: [get]	correct: [get]
# Count: 6
#
# participant_3_trial_33.txt
# wga<<g<hat to do when tnd<<he oil runs dry
# what to do when the oil runs dry
# replace: [g]	correct: [ha]
# replace: [h]	correct: [h]
# replace: [he]	correct: [he]
# Count: 3
#
# participant_3_trial_34.txt
# every apple dro<<<from e er<<<very tree
# every apple from every tree
# replace: [fro]	correct: [fro]
# replace: [ver]	correct: [ver]
# Count: 6
#
# participant_3_trial_35.txt
# tge<<he dow jones index has riae<<a<xe<<seb<n
# the dow jones index has risen
# replace: [he]	correct: [he]
# replace: [a]	correct: [se]
# replace: [x]	correct: [s]
# replace: [se]	correct: [se]
# replace: [n]	correct: [n]
# Count: 5
#
# participant_3_trial_36.txt
# you e<will loose yiy <<<our vou<ice
# you will loose your voice
# replace: [w]	correct: [w]
# replace: [our]	correct: [our]
# replace: [i]	correct: [i]
# Count: 5
#
# participant_3_trial_37.txt
# ec<xcesc<<ed the ma x<<ximy<u m<<m speed ,<limit
# exceed the maximum speed limit
# replace: [x]	correct: [x]
# replace: [ed]	correct: [ed]
# replace: [xi]	correct: [xi]
# replace: [u]	correct: [u]
# replace: [m ]	correct: [m ]
# replace: [l]	correct: [l]
# Count: 9
#
# participant_3_trial_38.txt
# prayer im <<n s h<c<<cg<hools offends some
# prayer in schools offends some
# replace: [n ]	correct: [n ]
# replace: [c]	correct: [h]
# replace: [cg]	correct: [ch]
# replace: [h]	correct: [h]
# Count: 4
#
# participant_3_trial_39.txt
# interacyin<<<tip<om<ns betwew<d<en men and wp<omen
# interactions between men and women
# replace: [tip]	correct: [tio]
# replace: [o]	correct: [o]
# replace: [n]	correct: [n]
# replace: [d]	correct: [e]
# replace: [e]	correct: [e]
# replace: [o]	correct: [o]
# Count: 6
#
# participant_3_trial_4.txt
# the first time he tried to swim
# the first time he tried to swim
# Count: 0
#
# participant_3_trial_40.txt
# the earlj<y birdge<< geys <<<ta<s thd<e worm
# the early bird gets the worm
# replace: [y]	correct: [y]
# replace: [ g]	correct: [ g]
# replace: [ta]	correct: [ts ]
# replace: [s]	correct: [s]
# replace: [e]	correct: [e]
# Count: 6
#
# participant_3_trial_41.txt
# reala<<<lations ate<<re vwr<<ery strained < <
# relations are very strained
# replace: [lat]	correct: [lat]
# replace: [re]	correct: [re]
# replace: [er]	correct: [er]
# replace: [ ]	correct: []
# replace: []	correct: []
# Count: 7
#
# participant_3_trial_42.txt
# s<z<a coupom<n for a cre<<<free za<<sample
# a coupon for a free sample
# replace: [z]	correct: [a]
# replace: [a]	correct: [a]
# replace: [n]	correct: [n]
# replace: [fre]	correct: [fre]
# replace: [sa]	correct: [sa]
# Count: 7
#
# participant_3_trial_43.txt
# dolphims<<ns leap high out of the water
# dolphins leap high out of the water
# replace: [ns]	correct: [ns]
# Count: 2
#
# participant_3_trial_44.txt
# seasones <<d golfers po<<love the gaj<me
# seasoned golfers love the game
# replace: [d ]	correct: [d ]
# replace: [lo]	correct: [lo]
# replace: [m]	correct: [m]
# Count: 5
#
# participant_3_trial_45.txt
# a swcurit<<<<<<ecurity v<foo<r c<<ce of eight thousand
# a security force of eight thousand
# replace: [ecurit]	correct: [ecurit]
# replace: [f]	correct: [f]
# replace: [r]	correct: [r]
# replace: [ce]	correct: [ce]
# Count: 10
#
# participant_3_trial_46.txt
# parkinf<g lots << is du<<full of trucks
# parking lot is full of trucks
# replace: [g]	correct: [g]
# replace: [ i]	correct: [ i]
# replace: [fu]	correct: [fu]
# Count: 5
#
# participant_3_trial_47.txt
# a good rezpi<<<spom<m<nse ro <<<r<to tge<<ge<<he qhwsti<<<<<uws<<ew<stion
# a good response to the question
# replace: [spo]	correct: [spo]
# replace: [m]	correct: [n]
# replace: [n]	correct: [n]
# replace: [r]	correct: [to ]
# replace: [t]	correct: [t]
# replace: [ge]	correct: [he]
# replace: [he]	correct: [he]
# replace: [uws]	correct: [uesti]
# replace: [ew]	correct: [es]
# replace: [s]	correct: [s]
# Count: 12
#
# participant_3_trial_48.txt
# fall is my fa our<<<<vorite ze<<season
# fall is my favorite season
# replace: [vori]	correct: [vori]
# replace: [se]	correct: [se]
# Count: 6
#
# participant_3_trial_5.txt
# important for political parties
# important for political parties
# Count: 0
#
# participant_3_trial_6.txt
# reading week is just about here
# reading week is just about here
# Count: 0
#
# participant_3_trial_7.txt
# wear a crown with many jewels
# wear a crown with many jewels
# Count: 0
#
# participant_3_trial_8.txt
# circumstances are unacceptable
# circumstances are unacceptable
# Count: 0
#
# participant_3_trial_9.txt
# win first prize in the contest
# win first prize in the contest
# Count: 0
#
# participant_4_trial_1.txt
# sprawling subdivisions are bad
# sprawling subdivisions are bad
# Count: 0
#
# participant_4_trial_10.txt
# the hopes of a new organization
# the hopes of a new organization
# Count: 0
#
# participant_4_trial_11.txt
# al< little enck<ouragement is needed
# a little encouragement is needed
# replace: [ ]	correct: [ ]
# replace: [o]	correct: [o]
# Count: 2
#
# participant_4_trial_12.txt
# reading week is just about here
# reading week is just about here
# Count: 0
#
# participant_4_trial_13.txt
# a problem with the e g<<g<ngi <ne
# a problem with the engine
# replace: [g]	correct: [ng]
# replace: [n]	correct: [n]
# replace: [n]	correct: [n]
# Count: 2
#
# participant_4_trial_14.txt
# double doun<ble toil and troub.e<<le
# double double toil and trouble
# replace: [b]	correct: [b]
# replace: [le]	correct: [le]
# Count: 3
#
# participant_4_trial_15.txt
# the food qt<<at this red<stajr<<ura g<<nt
# the food at this restaurant
# replace: [at]	correct: [at]
# replace: [s]	correct: [s]
# replace: [ur]	correct: [ur]
# replace: [nt]	correct: [nt]
# Count: 7
#
# participant_4_trial_16.txt
# a yard is almost as long as a  e<meter
# a yard is almost as long as a meter
# replace: [m]	correct: [e]
# Count: 0
#
# participant_4_trial_17.txt
# thar <<t ix<s q<a vrr<<ery odd question
# that is a very odd question
# replace: [t ]	correct: [t ]
# replace: [s]	correct: [s]
# replace: [a]	correct: [a]
# replace: [er]	correct: [er]
# Count: 6
#
# participant_4_trial_18.txt
# superman never wore a  mask
# superman never wore a mask
# Count: 0
#
# participant_4_trial_19.txt
# a rattle w<snake is very ppi<<oisonous
# a rattle snake is very poisonous
# replace: [s]	correct: [s]
# replace: [oi]	correct: [oi]
# Count: 3
#
# participant_4_trial_2.txt
# if at first you do not succeed
# if at first you do not succeed
# Count: 0
#
# participant_4_trial_20.txt
# what goes up mudt<<sr<t come doe<o<wn
# what goes up must come down
# replace: [sr]	correct: [st]
# replace: [t]	correct: [t]
# replace: [o]	correct: [w]
# replace: [w]	correct: [w]
# Count: 3
#
# participant_4_trial_21.txt
# important for politica.<l partirs<<i<es
# important for political parties
# replace: [l]	correct: [l]
# replace: [i]	correct: [es]
# replace: [e]	correct: [e]
# Count: 2
#
# participant_4_trial_22.txt
# the store will c.o<<lose at the<<en
# the store will close at ten
# replace: [lo]	correct: [lo]
# replace: [en]	correct: [en]
# Count: 4
#
# participant_4_trial_23.txt
# the registration prr<<eripd<<od is p<over
# the registration period is over
# replace: [er]	correct: [er]
# replace: [od]	correct: [od]
# replace: [o]	correct: [o]
# Count: 5
#
# participant_4_trial_24.txt
# the fo<irsy<t ti m<<me n<he tried tp<o swin< <m
# the first time he tried to swim
# replace: [i]	correct: [i]
# replace: [t]	correct: [t]
# replace: [me]	correct: [me]
# replace: [h]	correct: [h]
# replace: [o]	correct: [o]
# replace: [ ]	correct: [m]
# replace: [m]	correct: [m]
# Count: 7
#
# participant_4_trial_25.txt
# universally understood to be wrong
# universally understood to be wrong
# Count: 0
#
# participant_4_trial_26.txt
# fine but i<only in moderation
# fine but only in moderation
# replace: [o]	correct: [o]
# Count: 1
#
# participant_4_trial_27.txt
# sent this by registered mail
# sent this by registered mail
# Count: 0
#
# participant_4_trial_28.txt
# presidents drive expensive cars
# presidents drive expensive cars
# Count: 0
#
# participant_4_trial_29.txt
# do not feel bad<<<<  <too bad about it
# do not feel too bad about it
# replace: [  ]	correct: [ too]
# replace: [t]	correct: [t]
# Count: 2
#
# participant_4_trial_3.txt
# players must know alln< the rules
# players must know all the rules
# replace: [ ]	correct: [ ]
# Count: 1
#
# participant_4_trial_30.txt
# my preferred treat is chocolate
# my preferred treat is chocolate
# Count: 0
#
# participant_4_trial_31.txt
# this leather jacket id<s too warm
# this leather jacket is too warm
# replace: [s]	correct: [s]
# Count: 1
#
# participant_4_trial_32.txt
# are you sure you want this
# are you sure you want this
# Count: 0
#
# participant_4_trial_33.txt
# her majesty visited our country
# her majesty visited our country
# Count: 0
#
# participant_4_trial_34.txt
# what a monkey sees a monkey will do
# what a monkey sees a monkey will do
# Count: 0
#
# participant_4_trial_35.txt
# most judges are very honest
# most judges are very honest
# Count: 0
#
# participant_4_trial_36.txt
# please com<nfidential<<<<<<<<<<<<< keep this com<nfidential
# please keep this confidential
# replace: [n]	correct: [e]
# replace: [ keep this co]	correct: [ keep this co]
# replace: [n]	correct: [n]
# Count: 14
#
# participant_4_trial_37.txt
# caee<<reless driving results im <<n a fine
# careless driving results in a fine
# replace: [re]	correct: [re]
# replace: [n ]	correct: [n ]
# Count: 4
#
# participant_4_trial_38.txt
# dolphina<s leap out pf<<of <<<<<<<higj <<h pi<<ot<ut of the water
# dolphins leap high out of the water
# replace: [s]	correct: [s]
# replace: [of]	correct: [ o]
# replace: [higj ]	correct: [high ou]
# replace: [h ]	correct: [h ]
# replace: [ot]	correct: [ou]
# replace: [u]	correct: [u]
# Count: 9
#
# participant_4_trial_39.txt
# quick thetr<<re id <<s someone knocking
# quick there is someone knocking
# replace: [re]	correct: [re]
# replace: [s ]	correct: [s ]
# Count: 4
#
# participant_4_trial_4.txt
# the opposing team is over there
# the opposing team is over there
# Count: 0
#
# participant_4_trial_40.txt
# this is a non profi <t orgw<anization
# this is a non profit organization
# replace: [t]	correct: [t]
# replace: [a]	correct: [a]
# Count: 2
#
# participant_4_trial_41.txt
# tickets are very expem<nsive
# tickets are very expensive
# replace: [n]	correct: [n]
# Count: 1
#
# participant_4_trial_42.txt
# an inefficoen<<<ient wat<y tp<o keep <<<<<< heat a hpu<<ouse
# an inefficient way to heat a house
# replace: [ien]	correct: [ien]
# replace: [y]	correct: [y]
# replace: [o]	correct: [o]
# replace: [ heat ]	correct: [ heat ]
# replace: [ou]	correct: [ou]
# Count: 13
#
# participant_4_trial_43.txt
# fastet <<r than a speeding bullet
# faster than a speeding bullet
# replace: [r ]	correct: [r ]
# Count: 2
#
# participant_4_trial_44.txt
# we must edoub<<<<<redouble out<r efforts
# we must redouble our efforts
# replace: [redou]	correct: [redou]
# replace: [r]	correct: [r]
# Count: 6
#
# participant_4_trial_45.txt
# ran<indrops keep falling on mt <<y nraf<<<<head
# raindrops keep falling on my head
# replace: [i]	correct: [i]
# replace: [y ]	correct: [y ]
# replace: [head]	correct: [head]
# Count: 7
#
# participant_4_trial_46.txt
# listen tp<o five hours of opeta<<ra
# listen to five hours of opera
# replace: [o]	correct: [o]
# replace: [ra]	correct: [ra]
# Count: 3
#
# participant_4_trial_47.txt
# the furth<<<<out<rth edition wad <<s better
# the fourth edition was better
# replace: [out]	correct: [ourt]
# replace: [r]	correct: [r]
# replace: [s ]	correct: [s ]
# Count: 5
#
# participant_4_trial_48.txt
# never too rich a d<<nd never too thin
# never too rich and never too thin
# replace: [nd]	correct: [nd]
# Count: 2
#
# participant_4_trial_5.txt
# in sharp contrast to your words
# in sharp contrast to your words
# Count: 0
#
# participant_4_trial_6.txt
# what to do when the oil dr<<runs dry
# what to do when the oil runs dry
# replace: [ru]	correct: [ru]
# Count: 2
#
# participant_4_trial_7.txt
# house with new electrical panel
# house with new electrical panel
# Count: 0
#
# participant_4_trial_8.txt
# prepare for the exam in advance
# prepare for the exam in advance
# Count: 0
#
# participant_4_trial_9.txt
# i skimmed throk<ugh your proposal
# i skimmed through your proposal
# replace: [u]	correct: [u]
# Count: 1

# %%
a2.rawData.to_excel('rawData.xlsx')

# %%
a2.rawData.pivot_table( index='id', columns=["screenSize", 'type'], values= ['keyPressedTimes', 'time','deleteTimes', 'totalErrorRate'])
# Out:
#            deleteTimes                                keyPressedTimes  \
# screenSize       38 mm                42 mm                     38 mm
# type            normal      zoom     normal      zoom          normal
# id
# 1             5.583333  1.250000   6.333333  1.416667       40.583333
# 2             9.500000  0.916667  12.166667  1.083333       47.583333
# 3             8.083333  1.333333   5.833333  0.083333       46.166667
# 4             4.166667  0.500000   5.500000  1.833333       37.583333
#
#                                                   time                        \
# screenSize                 42 mm                 38 mm                 42 mm
# type             zoom     normal       zoom     normal       zoom     normal
# id
# 1           33.083333  42.250000  33.166667  22.607400  31.983758  22.147858
# 2           30.416667  55.250000  34.166667  31.337325  36.241608  36.960133
# 3           35.666667  41.416667  30.750000  27.670558  40.225783  26.505475
# 4           32.000000  42.166667  33.500000  24.047183  37.914067  19.973150
#
#                       totalErrorRate
# screenSize                     38 mm                42 mm
# type             zoom         normal      zoom     normal      zoom
# id
# 1           30.155158      18.352452  3.665598  14.151746  4.246927
# 2           52.086400      19.864309  3.028592  27.044734  6.515663
# 3           34.723925      17.755858  3.615051  23.518778  0.260417
# 4           31.936608      13.358230  1.501225  12.573403  3.826770

# %%
a2.totalErrorPivot()
# Out:
# screenSize      38 mm                42 mm
# type           normal      zoom     normal      zoom
# id
# 1           18.352452  3.665598  14.151746  4.246927
# 2           19.864309  3.028592  27.044734  6.515663
# 3           17.755858  3.615051  23.518778  0.260417
# 4           13.358230  1.501225  12.573403  3.826770

# %%
# import matplotlib.pyplot as plt
# df = a2.totalErrorPivot()
# plt.plot(df)
# import seaborn as sns
# sns.barplot(x='category', y='no_show_prop', hue='gender', data=df)

# %%
# Plotting Error Rate Graph
import seaborn as sns
sns.barplot(x='type', y='totalErrorRate', hue='screenSize', data=a2.rawData, capsize=.03, errwidth=1).set_title('Total Error Rate')
# %matplotlib inline

# %%
# Plotting Time Graph
sns.barplot(x='type', y='time', hue='screenSize', data=a2.rawData, capsize=.03, errwidth=1).set_title('Total Error Rate')
# %matplotlib inline

# %%
len("your presentation was inspiring")
